# %% [markdown]
# # Grouping incidents caused by metheorological events

# %% [markdown]
# ---
# ### Notebook Sections:
#
# 1. Utility functions definition
# 1. Data Cleaning
# 2. Exploratory Data Analysis
# 3. Clustering Incidents

# %% [markdown]
# ### Import modules and functions

# %%
import os, pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns; sns.set()
from IPython.display import clear_output as co

### Definir classe 'data' com endereço dos dados
class DATA:
    path = r'C:\Users\luisr\Desktop\Repositories\Dados\Desafio COR-Rio IV\\'
    AlertaAPI = r'http://websempre.rio.rj.gov.br/json/chuvas'

# %% [markdown]
# ### Load data

# %%
catalog = pd.read_csv('dados/incident_catalog.csv', parse_dates=True, infer_datetime_format=True)

# %% [markdown]
# #### Extract records of incidents of water bag formation (copy data for cleaning)

# %%
catalog = catalog[catalog['POP_TITULO']=="Bolsão d'água em via"].copy()
data = catalog.copy()

# %% [markdown]
# ---
# ## Utility functions

# %% [markdown]
# #### Format and correct street number text variable

# %%
def get_not_number(series):
    obj_index = []
    for index, number in zip(series.index, series):
        try:
            a = float(number) + 1
        except:
            obj_index.append(index)
    return series[obj_index]

import string

def drop_letters(text):
    for char in text:
        if char in string.ascii_letters:
            text = text.replace(char, '')
    return text

def drop_space(text):
    return text.replace(' ', '')

def drop_chars(text, chars=['°', 'º']):
    for char in chars:
        text = text.replace(char, '')
    return text

def split_avg(text, seps=['-', '/', ',']):
    if not text:
        return np.nan
    else:
        for sep in seps:
            if sep in text:
                items = [item for item in text.split(sep) if item]
                if len(items)==0:
                    return np.nan
                elif len(items)==1:
                    return items[0]
                else:
                    try:
                        return str(int(np.mean(np.array(items, dtype='int'))))
                    except:
                        return np.nan
        return text

# %% [markdown]
# #### Plot colored and connected coordinates in 2D plane

# %%
cmaps = [
    'Pastel1', 'Pastel2', 'Paired', 'Accent',
    'Dark2', 'Set1', 'Set2', 'Set3',
    'tab10', 'tab20', 'tab20b', 'tab20c'
]

from sklearn.preprocessing import LabelEncoder as le

def scatter_cordinates_colored(lat, lng, groups, cmap=None, title='', figsize=None):
    cMap = plt.get_cmap(cmap) if cmap else None
    labels = pd.Series(le().fit_transform(groups), index=groups.index)
    plt.figure(figsize=figsize)
    for label in labels.unique():
        msk = labels==label
        plt.scatter(lat[msk], lng[msk], c=(cMap(label) if cmap else None), cmap=cMap)
    plt.xlabel('Latitude'); plt.ylabel('Longitude'); plt.title(title); plt.show()

def connect_cordinates_colored(lat, lng, groups, numbers, cmap='tab10', title='', figsize=None):
    cmap = plt.get_cmap(cmap)
    labels = pd.Series(le().fit_transform(groups), index=groups.index)
    plt.figure(figsize=figsize)
    for label in labels.unique():
        group_index = numbers[labels==label].sort_values().index
        group_lat, group_lng = lat.loc[group_index], lng.loc[group_index]
        plt.plot(group_lat, group_lng)
        plt.scatter(group_lat, group_lng, s=30)
    plt.xlabel('Latitude'); plt.ylabel('Longitude'); plt.title(title); plt.show()

def min_group_size_progression_plot(data, coord_cols, group_col, max_incidents=15, color='blue', figsize=None, pause=0.3):
    route_count = data[group_col].value_counts(); recurrence = []
    for min_incidents in range(max_incidents+1):
        rec_routes = route_count[route_count>=min_incidents]
        rec_data = data[data[group_col].isin(rec_routes.index)]
        n_routes = len(rec_routes)
        n_incidents = rec_data.shape[0]
        p_routes = round(n_routes / route_count.shape[0] * 100, 1)
        p_incidents = round(n_incidents / data.shape[0] * 100, 1)
        recurrence.append([min_incidents, n_routes, n_incidents, p_routes, p_incidents])
        fig = plt.figure(figsize=figsize); ax = fig.add_subplot(111)
        rec_data.plot(
            coord_cols[0], coord_cols[1],
            kind='scatter', c=color, ax=ax,
            title=f'''Min Incidents per Route: {min_incidents} / {max_incidents}.
Routes: {n_routes} / {route_count.shape[0]} ({p_routes} %). Incidents: {n_incidents} / {data.shape[0]} ({p_incidents} %)''',
        )
        plt.show(); plt.pause(pause); co(wait=True)
    return pd.DataFrame(recurrence, columns=['min_incidents', 'n_routes', 'n_incidents', 'p_routes (%)', 'p_incidents (%)']); # recurrence_df

# %% [markdown]
# ---
# # Data Cleaning

# %%
data.dtypes
# Out:
# EVENTO_ID              int64
# EVENTO_TITULO         object
# EVENTO_DESCRICAO      object
# EVENTO_GRAVIDADE      object
# EVENTO_BAIRRO         object
# STATUS                object
# EVENTO_PRAZO          object
# POP_TITULO            object
# POP_DESCRICAO         object
# evento_inicio         object
# evento_fim            object
# lat                  float64
# lng                  float64
# formatted_address     object
# place_id              object
# types                 object
# search_lat           float64
# search_lng           float64
# location_type         object
# route                 object
# street_number         object
# postal_code           object
# premise               object
# dtype: object

# %% [markdown]
# #### Format and correct street number variable

# %%
not_number = get_not_number(catalog['street_number'])
not_number_corrected = not_number.map(drop_letters).map(drop_space).map(drop_chars).map(split_avg)

data.loc[not_number.index, ['street_number']] = not_number_corrected

data.dropna(subset=['street_number'], inplace=True) # drop rows where street number is missing

# %% [markdown]
# #### Data type conversion

# %%
float_cols = ['lat', 'lng', 'search_lat', 'search_lng', 'street_number']
data[float_cols] = data[float_cols].astype(float)

# %% [markdown]
# ---
# # Exploratory Data Analysis

# %% [markdown]
# ### 1. Coordinades visualization

# %% [markdown]
# #### Scatter plot of original coordinates

# %%
data.plot('lat', 'lng', kind='scatter', c='blue', figsize=(10, 6)); plt.show()

# %% [markdown]
# #### Extracting incidents of routes with at least 'min_incidents' incidents registered

# %%
recurrence = min_group_size_progression_plot(data, ['lat', 'lng'], 'route', max_incidents=15, color='blue', figsize=(10, 6), pause=0.3)

# %% [markdown]
# ### 2. Incidents per route analysis

# %% [markdown]
# #### Percentage of routes and incidents left in top 50 routes

# %%
recurrence[recurrence['n_routes']<51]
# Out:
#     min_incidents  n_routes  n_incidents  p_routes (%)  p_incidents (%)
# 11             11        50         1546           6.9             51.8
# 12             12        45         1491           6.2             50.0
# 13             13        38         1407           5.2             47.2
# 14             14        35         1368           4.8             45.9
# 15             15        34         1354           4.7             45.4

# %% [markdown]
# #### Incidents per route

# %%
route_count = data['route'].value_counts().rename('Incident Count')
fig, ax = plt.subplots(figsize=(5, 3))
route_count.head(15).plot.bar(
    title='Incidents count per route',
)
ax.set(
    ylabel='Incidents',
    xlabel='Route'
)
plt.show()

# %% [markdown]
# #### Extracting incidents of top 50 routes (min 10 incidents)

# %%
min_incidents = 10
rec_routes = route_count[route_count>min_incidents]
rec_data = data[data['route'].isin(rec_routes.index)]
rec_routes.tail()
# Out:
# Rua da Feira                  11
# Avenida Mem de Sá             11
# Rua da América                11
# Rua Siqueira Campos           11
# Avenida Aquarela do Brasil    11
# Name: Incident Count, dtype: int64

# %% [markdown]
# ### 3. Routes Visualization

# %% [markdown]
# #### Line & Scatter plot of coordinates (colored and connected by routes)

# %%
scatter_cordinates_colored(
    rec_data['lat'], rec_data['lng'], rec_data['route'], #cmap='tab10',
    title='Coordinates Scatter Plot Colored by Route - Top 50 Routes',
    figsize=(12, 8)
)

# %% [markdown]
# #### Line & Scatter plot of coordinates (colored and connected by routes)

# %%
connect_cordinates_colored(
    rec_data['search_lat'], rec_data['search_lng'],
    rec_data['route'], rec_data['street_number'], cmap=None,
    title='Incident coordinates Connected and Colored Line & Scatter Plot - Top 50 Routes',
    figsize=(12, 8)
)

# %% [markdown]
# ### 4. Street numbers statistical analysis

# %% [markdown]
# #### Street numbers statistical description per route (top 10)

# %%
number_desc = rec_data.groupby('route')['street_number'].describe().sort_values('count', ascending=False)
number_desc.head(10)
# Out:
#                                 count         mean          std    min  \
# route
# Avenida Brasil                  235.0  4914.454745  8170.248330   13.0
# Avenida Armando Lombardi        123.0   339.861789   430.901577   33.0
# Rua do Catete                    87.0   175.724138    55.524285    1.0
# Avenida Epitácio Pessoa          81.0  1629.308642  1413.060178    5.0
# Avenida Ayrton Senna             74.0  2434.189189  2388.383282   80.0
# Avenida das Américas             57.0  5079.501754  6514.539946   12.3
# Avenida Engenheiro Souza Filho   44.0  1374.454545   801.623018   10.0
# Estrada da Barra da Tijuca       43.0  1426.906977   634.024103  186.0
# Avenida Ministro Ivan Lins       41.0   749.097561   354.292662   11.0
# Avenida Presidente Vargas        39.0  1722.846154  1309.906295   74.0
#
#                                    25%     50%      75%      max
# route
# Avenida Brasil                   211.0   500.0  5420.00  35025.0
# Avenida Armando Lombardi         188.0   188.0   350.00   3652.0
# Rua do Catete                    139.0   195.0   228.00    228.0
# Avenida Epitácio Pessoa          165.0  1612.0  2690.00   4800.0
# Avenida Ayrton Senna             300.0  2400.0  4581.75   9001.0
# Avenida das Américas             801.0  2250.0  4444.00  20035.0
# Avenida Engenheiro Souza Filho   586.5  1190.0  2100.00   2631.0
# Estrada da Barra da Tijuca      1030.0  1636.0  1716.00   3163.0
# Avenida Ministro Ivan Lins       740.0   850.0   850.00   1770.0
# Avenida Presidente Vargas        220.0  2617.0  2863.00   3364.0

# %% [markdown]
# #### Routes' street numbers ranges statistical description

# %%
number_ranges = ( number_desc['max'] - number_desc['min'] ).to_frame('Street Numbers Range')
number_ranges.describe()
# Out:
#        Street Numbers Range
# count             50.000000
# mean            3233.428600
# std             6083.758546
# min                0.000000
# 25%              276.500000
# 50%             1066.000000
# 75%             2975.654750
# max            35012.000000

# %% [markdown]
# #### Linear incident density (per 100 m) per route - Top 10

# %%
route_numbers_density = ( route_count / number_ranges['Street Numbers Range'] * 100 ).sort_values(ascending=False).to_frame('Incidents per 100 m')
density_per_route = route_numbers_density[route_numbers_density.index.isin(rec_routes.index)]
density = pd.concat([density_per_route, rec_routes, number_ranges], 1); density.head(10)
# Out:
#                             Incidents per 100 m  Incident Count  \
# Rua 6                                       inf              18
# Avenida Aquarela do Brasil                  inf              11
# Rua do Catete                         38.325991              87
# Estrada da Cancela Preta              28.571429              24
# Rua Silveira Martins                  16.891892              25
# Rua Vinícius de Moraes                10.104530              29
# Rua Tonelero                          10.030395              33
# Rua Haddock Lobo                       9.248555              32
# Rua Siqueira Campos                    7.971014              11
# Avenida Ernani Cardoso                 6.862745              14
#
#                             Street Numbers Range
# Rua 6                                        0.0
# Avenida Aquarela do Brasil                   0.0
# Rua do Catete                              227.0
# Estrada da Cancela Preta                    84.0
# Rua Silveira Martins                       148.0
# Rua Vinícius de Moraes                     287.0
# Rua Tonelero                               329.0
# Rua Haddock Lobo                           346.0
# Rua Siqueira Campos                        138.0
# Avenida Ernani Cardoso                     204.0

# %% [markdown]
# #### Linear Incident density statistical description

# %%
route_numbers_density.describe()
# Out:
#        Incidents per 100 m
# count            50.000000
# mean                   inf
# std                    NaN
# min               0.124384
# 25%               0.972865
# 50%               2.336738
# 75%               4.707822
# max                    inf

# %% [markdown]
# #### Route with smallest incident density in top 50 routes

# %%
density.iloc[[49]]
# Out:
#                            Incidents per 100 m  Incident Count  \
# Avenida Dom Hélder Câmara             0.124384              12
#
#                            Street Numbers Range
# Avenida Dom Hélder Câmara              9647.545

# %% [markdown]
# ---
# # Clustering Incidents

# %% [markdown]
# #### Setting automatic clustering algorithms

# %%
import sklearn.cluster as cluster
from sklearn.preprocessing import MinMaxScaler as mms, LabelEncoder as le

dbscan = cluster.DBSCAN(eps=0.025, min_samples=3)
optics = cluster.OPTICS(min_samples=3, max_eps=0.025)
mean = cluster.MeanShift(bandwidth=0.025, cluster_all=False, max_iter=1000)
aff = cluster.AffinityPropagation(damping=0.75, max_iter=1000, random_state=0)

algs = [dbscan, optics, mean, aff]

# %%
a = algs[0]
a?

# %% [markdown]
# ### 1. Clustering by geodetic coordinates

# %% [markdown]
# ##### Fit different algorithms

# %%
coords = mms().fit_transform(rec_data[['lat', 'lng', 'street_number']])
for alg in algs[:4]:
    alg.fit(coords)
# Out:
# c:\Users\luisr\anaconda3\lib\site-packages\sklearn\cluster\_optics.py:803: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]
# c:\Users\luisr\anaconda3\lib\site-packages\sklearn\cluster\_affinity_propagation.py:246: ConvergenceWarning: Affinity propagation did not converge, this model will not have any cluster centers.
#   warnings.warn("Affinity propagation did not converge, this model "

# %% [markdown]
# ##### Cluster algorithm comparison

# %%
fig = plt.figure(figsize=(14, 6), tight_layout=True)
axs = [fig.add_subplot(2, 3, i) for i in range(1, len(algs)+1)]
for ax, alg in zip(axs, algs):
    for label in np.unique(alg.labels_):
        msk = alg.labels_==label
        ax.scatter(rec_data['lat'][msk], rec_data['lng'][msk]) #, c=alg.labels_)
    ax.set(title=f'{type(alg).__name__} - {len(np.unique(alg.labels_))} clusters found')
plt.show()

# %% [markdown]
# ### 2. Clustering by street number per route

# %% [markdown]
# #### Clustering street numbers of routes separatelly

# %% [markdown]
# ##### Fit different algorithms

# %%
route_numbers = {}
for route in rec_routes.index:
    route_numbers[route] = rec_data.loc[rec_data['route']==route, ['street_number']].dropna().values.tolist()

numbers = mms().fit_transform(route_numbers[route_count.index[0]])
for alg in algs:
    alg.fit(numbers)
# Out:
# c:\Users\luisr\anaconda3\lib\site-packages\sklearn\cluster\_optics.py:803: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]

# %% [markdown]
# ##### Cluster algorithm comparison

# %%
fig = plt.figure(figsize=(14, 6), tight_layout=True)
axs = [fig.add_subplot(2, 3, i) for i in range(1, len(algs)+1)]
for ax, alg in zip(axs, algs):
    for label in np.unique(alg.labels_):
        msk = alg.labels_==label
        ax.scatter(numbers[msk], np.zeros(sum(msk))) #, c=alg.labels_, cmap='tab10')
    ax.set(title=f'{type(alg).__name__} - {len(np.unique(alg.labels_))} clusters found')
plt.show()
