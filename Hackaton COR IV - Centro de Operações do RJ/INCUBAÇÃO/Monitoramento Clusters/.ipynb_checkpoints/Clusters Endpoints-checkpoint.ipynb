# %%
cd ../../../../Apps/Python/bolsao-api
# Out:
# C:\Users\luisr\Desktop\Repositories\Apps\Python\bolsao-api

# %%
from warnings import filterwarnings as fws; fws('ignore')
import requests, json, pandas as pd
from copy import deepcopy

# ---
# custom modules

from modules.mongo_requests import last_prediction_record
from modules.comando_endpoints import get_clusters_events #, polygons_geojson
from modules.waze_endpoints import get_clusters_waze_partner_alerts
from modules.geojson_conversion import drop_props, add_props, update_props_by_id, geojson_obj
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-48-c5d731b09629> in <module>
#       9 from modules.comando_endpoints import get_clusters_events #, polygons_geojson
#      10 from modules.waze_endpoints import get_clusters_waze_partner_alerts
# ---> 11 from modules.geojson_conversion import drop_props, add_props, update_props_by_id, geojson_obj
#
# ImportError: cannot import name 'geojson_obj' from 'modules.geojson_conversion' (C:\Users\luisr\Desktop\Repositories\Apps\Python\bolsao-api\modules\geojson_conversion.py)

# %% [markdown]
# ---

# %% [markdown]
# ## Load local geojson

# %%
clusters_geojson = json.loads(open('static/clusters/polygons_micro.geojson').read())

# Extra
clusters_df = pd.read_csv('./static/clusters/clusters_micro.csv')
clusters_json = json.dumps(clusters_df.to_dict(orient='records'), indent=4)

# %% [markdown]
# #### Filter geojson features

# %%
outlier_polygon = lambda feat: feat['properties']['sublabel'] != -1

clusters_geojson['features'] = list(filter(outlier_polygon, clusters_geojson['features']))

# %% [markdown]
# #### Delete geojson properties

# %%
keep_cols = [
    'sublabel', 'main_neighborhood', 'main_route', 'main_street_number_range',
    'lat_centroid', 'lng_centroid', 'label_count', 'area_box', 'area_circle'
]

clusters_geojson['features'] = drop_props(clusters_geojson['features'], keep_cols)

# %% [markdown]
# ## Get external data
#
# #### Waze data

# %%
waze = get_clusters_waze_partner_alerts()

# %% [markdown]
# #### Comando data

# %%
comando = get_clusters_events()
# Out:
# Comando open events: Request attempt (1)

# %% [markdown]
# #### Probability data

# %%
prob = pd.DataFrame(last_prediction_record(mongo_timeout=1000*5, load_limit=500))
# Out:
# Endpoint Request: /predict

# %% [markdown]
# ## Append properties to geojson by id field

# %% [markdown]
# #### Append waze data

# %%
waze_drop = ['alerts_ids', 'waterbag_alerts_ids']

clusters_geojson['features'] = update_props_by_id(        # for same lenght and order features and dataframes
    clusters_geojson['features'],
    waze,
    id_col='sublabel',
    id_col_df='cluster_id',
    drop=waze_drop
)

# %% [markdown]
# #### Append comando data

# %%
comando_drop = ['events_ids', 'waterbag_events_ids']

clusters_geojson['features'] = update_props_by_id(        # for same lenght and order features and dataframes
    clusters_geojson['features'],
    comando,
    id_col='sublabel',
    id_col_df='cluster_id',
    drop=comando_drop
)

# %% [markdown]
# #### Append probability data

# %%
prob_drop = ['_id', 'cluster', 'range']

clusters_geojson['features'] = update_props_by_id(        # for same lenght and order features and dataframes
    clusters_geojson['features'],
    prob,
    id_col='sublabel',
    id_col_df='cluster_id',
    drop=prob_drop
)

# %% [markdown]
# ---
# ## Build full dinamic geojson polygons endpoint

# %%
## Clusters endpoint settings

#### Clusters geojson properties settings
keep_clusters_cols = [
    'sublabel', 'main_neighborhood', 'main_route', 'main_street_number_range',
    'lat_centroid', 'lng_centroid', 'label_count', 'area_box', 'area_circle'
]
waze_drop = ['alerts_ids', 'waterbag_alerts_ids']
comando_drop = ['events_ids', 'waterbag_events_ids']
prob_drop = ['_id', 'cluster', 'range']

## Local resources

#### Load data
clusters_geojson = json.loads(open('static/clusters/polygons_micro.geojson').read())
clusters_df = pd.read_csv('./static/clusters/clusters_micro.csv')
clusters_json = json.dumps(clusters_df.to_dict(orient='records'), indent=4)

#### Filter geojson features (outlier polygon)
outlier_polygon = lambda feat: feat['properties']['sublabel'] != -1
clusters_geojson['features'] = list(filter(outlier_polygon, clusters_geojson['features']))

#### Delete clusters geojson properties
clusters_geojson['features'] = drop_props(clusters_geojson['features'], keep_clusters_cols)

## Get and append current monitoring data
def clusters_dinamic():
    features = deepcopy(clusters_geojson['features']) # Copy features to keep originl intact
    waze = get_clusters_waze_partner_alerts() # Waze data
    comando = get_clusters_events() # Comando data
    prob = pd.DataFrame(last_prediction_record(mongo_timeout=1000*5, load_limit=500)) # Probability data
    for df, drop_cols in zip([waze, comando, prob], [waze_drop, comando_drop, prob_drop]): 
        features = update_props_by_id(
            features, df,
            id_col='sublabel',
            id_col_df='cluster_id',
            drop=drop_cols
        )    
    return features

## Get external data
features = clusters_dinamic()
# Out:
# Comando open events: Request attempt (1)
# Endpoint Request: /predict

# %% [markdown]
# ## See final result

# %%
features
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3128293, -23.0071335],
#      [-43.3128293, -23.0062307],
#      [-43.3081833, -23.0062307],
#      [-43.3081833, -23.0071335],
#      [-43.3128293, -23.0071335]]]},
#   'properties': {'sublabel': 0,
#    'main_neighborhood': 'Barra da Tijuca',
#    'main_route': 'Avenida Armando Lombardi',
#    'main_street_number_range': '3098 - 67',
#    'lat_centroid': -23.00663077719302,
#    'lng_centroid': -43.31023211228073,
#    'label_count': 114,
#    'area_box': 0.047619992468992,
#    'area_circle': 0.1781739507627371,
#    'alerts': 3,
#    'alerts_status': 1,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0,
#    'timestamp': '2022-12-22 00:15:00.022000',
#    'date': '2022-12-21',
#    'time': '21:15:00',
#    'probability': 0.477012,
#    'confidence': 0.045977,
#    'label': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1786045, -22.9271983],
#      [-43.1786045, -22.925534],
#      [-43.1755488, -22.925534],
#      [-43.1755488, -22.9271983],
#      [-43.1786045, -22.9271983]]]},
#   'properties': {'sublabel': 1,
#    'main_neighborhood': 'Catete',
#    'main_route': 'Rua do Catete',
#    'main_street_number_range': '228 - 139',
#    'lat_centroid': -22.926423254545423,
#    'lng_centroid': -43.17684174949493,
#    'label_count': 99,
#    'area_box': 0.0577714177166502,
#    'area_circle': 0.0771649864324882,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0,
#    'timestamp': '2022-12-22 00:15:00.022000',
#    'date': '2022-12-21',
#    'time': '21:15:00',
#    'probability': 0.569684,
#    'confidence': 0.139368,
#    'label': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1875, -22.9677391],
#      [-43.1875, -22.9661813],
#      [-43.1852321, -22.9661813],
#      [-43.1852321, -22.9677391],
#      [-43.1875, -22.9677391]]]},
#   'properties': {'sublabel': 2,
#    'main_neighborhood': 'Copacabana',
#    'main_route': 'Rua Tonelero',
#    'main_street_number_range': '236 - 9',
#    'lat_centroid': -22.96679250930232,
#    'lng_centroid': -43.185999472093,
#    'label_count': 43,
#    'area_box': 0.0401216687150346,
#    'area_circle': 0.0424803018920543,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0,
#    'timestamp': '2022-12-22 00:15:00.022000',
#    'date': '2022-12-21',
#    'time': '21:15:00',
#    'probability': 0.281216,
#    'confidence': 0.437567,
#    'label': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2041, -22.9804377],
#      [-43.2041, -22.97923560000001],
#      [-43.2012, -22.97923560000001],
#      [-43.2012, -22.9804377],
#      [-43.2041, -22.9804377]]]},
#   'properties': {'sublabel': 3,
#    'main_neighborhood': 'Ipanema',
#    'main_route': 'Avenida Epitácio Pessoa',
#    'main_street_number_range': '1910 - 1602',
#    'lat_centroid': -22.97973525833334,
#    'lng_centroid': -43.20253954166667,
#    'label_count': 36,
#    'area_box': 0.0395859932472244,
#    'area_circle': 0.0694470026490717,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0,
#    'timestamp': '2022-12-22 00:15:00.022000',
#    'date': '2022-12-21',
#    'time': '21:15:00',
#    'probability': 0.051812,
#    'confidence': 0.896377,
#    'label': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3004865, -23.0130858],
#      [-43.3004865, -23.0120545],
#      [-43.2959843, -23.0120545],
#      [-43.2959843, -23.0130858],
#      [-43.3004865, -23.0130858]]]},
#   'properties': {'sublabel': 4,
#    'main_neighborhood': 'Barra da Tijuca',
#    'main_route': 'Avenida Ministro Ivan Lins',
#    'main_street_number_range': '1770 - 11',
#    'lat_centroid': -23.012736447222228,
#    'lng_centroid': -43.298338836111135,
#    'label_count': 36,
#    'area_box': 0.0527120425238098,
#    'area_circle': 0.1673006678670963,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0,
#    'timestamp': '2022-12-22 00:15:00.022000',
#    'date': '2022-12-21',
#    'time': '21:15:00',
#    'probability': 0.772759,
#    'confidence': 0.545518,
#    'label': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2643778, -22.9975628],
#      [-43.2643778, -22.9971128],
#      [-43.2626, -22.9971128],
#      [-43.2626, -22.9975628],
#      [-43.2643778, -22.9975628]]]},
#   'properties': {'sublabel': 5,
#    'main_neighborhood': 'São Conrado',
#    'main_route': 'Autoestrada Engenheiro Fernando Mac Dowell',
#    'main_street_number_range': '625 - 601',
#    'lat_centroid': -22.99721993823529,
#    'lng_centroid': -43.26289011764704,
#    'label_count': 34,
#    'area_box': 0.0090832939136925,
#    'area_circle': 0.0260922419554927,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.225295, -22.8896812],
#      [-43.225295, -22.8873898],
#      [-43.222, -22.8873898],
#      [-43.222, -22.8896812],
#      [-43.225295, -22.8896812]]]},
#   'properties': {'sublabel': 6,
#    'main_neighborhood': 'Caju',
#    'main_route': 'Avenida Brasil',
#    'main_street_number_range': '1765 - 365',
#    'lat_centroid': -22.88856276470588,
#    'lng_centroid': -43.22377519999999,
#    'label_count': 34,
#    'area_box': 0.0857917332960742,
#    'area_circle': 0.0897740174560383,
#    'alerts': 1,
#    'alerts_status': 1,
#    'waterbag_alerts': 1,
#    'waterbag_alerts_status': 1,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2356, -22.8860074],
#      [-43.2356, -22.8849165],
#      [-43.234106, -22.8849165],
#      [-43.234106, -22.8860074],
#      [-43.2356, -22.8860074]]]},
#   'properties': {'sublabel': 7,
#    'main_neighborhood': 'Manguinhos',
#    'main_route': 'Avenida Brasil',
#    'main_street_number_range': '3666 - 14',
#    'lat_centroid': -22.88516676176472,
#    'lng_centroid': -43.235061679411785,
#    'label_count': 34,
#    'area_box': 0.0185197135424475,
#    'area_circle': 0.0184569771933004,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2550491, -22.993673],
#      [-43.2550491, -22.9924558],
#      [-43.2509, -22.9924558],
#      [-43.2509, -22.993673],
#      [-43.2550491, -22.993673]]]},
#   'properties': {'sublabel': 8,
#    'main_neighborhood': 'Rocinha',
#    'main_route': 'Avenida Aquarela do Brasil',
#    'main_street_number_range': '1 - 1',
#    'lat_centroid': -22.99303091000001,
#    'lng_centroid': -43.25337113333333,
#    'label_count': 30,
#    'area_box': 0.057342580297879,
#    'area_circle': 0.1421283565197328,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1841, -22.9460416],
#      [-43.1841, -22.9447735],
#      [-43.1821018, -22.9447735],
#      [-43.1821018, -22.9460416],
#      [-43.1841, -22.9460416]]]},
#   'properties': {'sublabel': 9,
#    'main_neighborhood': 'Botafogo',
#    'main_route': 'Praia de Botafogo',
#    'main_street_number_range': '360 - 314',
#    'lat_centroid': -22.94552983928572,
#    'lng_centroid': -43.18313875000001,
#    'label_count': 28,
#    'area_box': 0.028780840262179,
#    'area_circle': 0.0329879486844467,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2067, -22.91018930000001],
#      [-43.2067, -22.908516],
#      [-43.2022, -22.908516],
#      [-43.2022, -22.91018930000001],
#      [-43.2067, -22.91018930000001]]]},
#   'properties': {'sublabel': 10,
#    'main_neighborhood': 'Cidade Nova',
#    'main_route': 'Avenida Presidente Vargas',
#    'main_street_number_range': '3102 - 74',
#    'lat_centroid': -22.909389603333334,
#    'lng_centroid': -43.20452359333333,
#    'label_count': 30,
#    'area_box': 0.0855480875403851,
#    'area_circle': 0.1673910786430428,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2053, -22.9618296],
#      [-43.2053, -22.960045],
#      [-43.2024324, -22.960045],
#      [-43.2024324, -22.9618296],
#      [-43.2053, -22.9618296]]]},
#   'properties': {'sublabel': 11,
#    'main_neighborhood': 'Jardim Botânico',
#    'main_route': 'Rua Professor Saldanha',
#    'main_street_number_range': '94 - 24',
#    'lat_centroid': -22.960866507142853,
#    'lng_centroid': -43.204399389285705,
#    'label_count': 28,
#    'area_box': 0.0581194843449582,
#    'area_circle': 0.0679227725599056,
#    'alerts': 1,
#    'alerts_status': 1,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.24116470000001, -22.879865],
#      [-43.24116470000001, -22.8781176],
#      [-43.2395, -22.8781176],
#      [-43.2395, -22.879865],
#      [-43.24116470000001, -22.879865]]]},
#   'properties': {'sublabel': 12,
#    'main_neighborhood': 'Manguinhos',
#    'main_route': 'Avenida Brasil',
#    'main_street_number_range': '170 - 13',
#    'lat_centroid': -22.878798567857142,
#    'lng_centroid': -43.240493096428565,
#    'label_count': 28,
#    'area_box': 0.0330557690647559,
#    'area_circle': 0.029410458133313,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.4526495, -22.8612166],
#      [-43.4526495, -22.8601992],
#      [-43.4522323, -22.8601992],
#      [-43.4522323, -22.8612166],
#      [-43.4526495, -22.8612166]]]},
#   'properties': {'sublabel': 13,
#    'main_neighborhood': 'Padre Miguel',
#    'main_route': 'Estrada da Cancela Preta',
#    'main_street_number_range': '111 - 27',
#    'lat_centroid': -22.861174025,
#    'lng_centroid': -43.45229029285717,
#    'label_count': 28,
#    'area_box': 0.0048240534678784,
#    'area_circle': 0.0099700789689301,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.217713, -22.921571],
#      [-43.217713, -22.9200224],
#      [-43.2156725, -22.9200224],
#      [-43.2156725, -22.921571],
#      [-43.217713, -22.921571]]]},
#   'properties': {'sublabel': 14,
#    'main_neighborhood': 'Tijuca',
#    'main_route': 'Rua Haddock Lobo',
#    'main_street_number_range': '359 - 210',
#    'lat_centroid': -22.920486426923077,
#    'lng_centroid': -43.216488084615385,
#    'label_count': 26,
#    'area_box': 0.0358974830505029,
#    'area_circle': 0.0344118132388436,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.218050700000006, -22.9733447],
#      [-43.218050700000006, -22.9720306],
#      [-43.2164, -22.9720306],
#      [-43.2164, -22.9733447],
#      [-43.218050700000006, -22.9733447]]]},
#   'properties': {'sublabel': 15,
#    'main_neighborhood': 'Lagoa',
#    'main_route': 'Rua 6',
#    'main_street_number_range': '35 - 35',
#    'lat_centroid': -22.97271202307693,
#    'lng_centroid': -43.21738338846154,
#    'label_count': 26,
#    'area_box': 0.0246332645460299,
#    'area_circle': 0.0225029524403021,
#    'alerts': 3,
#    'alerts_status': 1,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 1,
#    'events_status': 1,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2108155, -22.906394100000004],
#      [-43.2108155, -22.9042645],
#      [-43.2094, -22.9042645],
#      [-43.2094, -22.906394100000004],
#      [-43.2108155, -22.906394100000004]]]},
#   'properties': {'sublabel': 16,
#    'main_neighborhood': 'Santo Cristo',
#    'main_route': 'Avenida Francisco Bicalho',
#    'main_street_number_range': '2215 - 47',
#    'lat_centroid': -22.90534148076923,
#    'lng_centroid': -43.20994048076923,
#    'label_count': 26,
#    'area_box': 0.0342487311155548,
#    'area_circle': 0.0436833644259226,
#    'alerts': 2,
#    'alerts_status': 1,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.320401200000006, -22.82055230000001],
#      [-43.320401200000006, -22.820402800000004],
#      [-43.3200086, -22.820402800000004],
#      [-43.3200086, -22.82055230000001],
#      [-43.320401200000006, -22.82055230000001]]]},
#   'properties': {'sublabel': 17,
#    'main_neighborhood': 'Irajá',
#    'main_route': 'Avenida Brasil',
#    'main_street_number_range': '345 - 257',
#    'lat_centroid': -22.820481092,
#    'lng_centroid': -43.320377256,
#    'label_count': 25,
#    'area_box': 0.0006672569149163,
#    'area_circle': 0.0012757712124714,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2065, -22.9743299],
#      [-43.2065, -22.9742378],
#      [-43.20639050000001, -22.9742378],
#      [-43.20639050000001, -22.9743299],
#      [-43.2065, -22.9743299]]]},
#   'properties': {'sublabel': 18,
#    'main_neighborhood': 'Lagoa',
#    'main_route': 'Avenida Epitácio Pessoa',
#    'main_street_number_range': '165 - 165',
#    'lat_centroid': -22.97426432500001,
#    'lng_centroid': -43.206479937500006,
#    'label_count': 24,
#    'area_box': 0.0001145233757691,
#    'area_circle': 9.901961605425317e-05,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1905, -22.9501064],
#      [-43.1905, -22.9493737],
#      [-43.1887411, -22.9493737],
#      [-43.1887411, -22.9501064],
#      [-43.1905, -22.9501064]]]},
#   'properties': {'sublabel': 19,
#    'main_neighborhood': 'Botafogo',
#    'main_route': 'Rua São Clemente',
#    'main_street_number_range': '250 - 188',
#    'lat_centroid': -22.949625752173915,
#    'lng_centroid': -43.18974730000001,
#    'label_count': 23,
#    'area_box': 0.014637427742263,
#    'area_circle': 0.0255583049977297,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3337, -22.9795704],
#      [-43.3337, -22.9781155],
#      [-43.333, -22.9781155],
#      [-43.333, -22.9795704],
#      [-43.3337, -22.9795704]]]},
#   'properties': {'sublabel': 20,
#    'main_neighborhood': 'Itanhangá',
#    'main_route': 'Avenida Engenheiro Souza Filho',
#    'main_street_number_range': '2593 - 26',
#    'lat_centroid': -22.978609422727278,
#    'lng_centroid': -43.33359770909094,
#    'label_count': 22,
#    'area_box': 0.0115647768320885,
#    'area_circle': 0.0203889252476641,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1861477, -22.9126],
#      [-43.1861477, -22.9103994],
#      [-43.183956, -22.9103994],
#      [-43.183956, -22.9126],
#      [-43.1861477, -22.9126]]]},
#   'properties': {'sublabel': 21,
#    'main_neighborhood': 'Centro',
#    'main_route': 'Avenida Mem de Sá',
#    'main_street_number_range': '178 - 148',
#    'lat_centroid': -22.91147689523809,
#    'lng_centroid': -43.18518414761903,
#    'label_count': 21,
#    'area_box': 0.0547948162603771,
#    'area_circle': 0.0466447634459839,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3654, -22.9829389],
#      [-43.3654, -22.9824279],
#      [-43.3628, -22.9824279],
#      [-43.3628, -22.9829389],
#      [-43.3654, -22.9829389]]]},
#   'properties': {'sublabel': 22,
#    'main_neighborhood': 'Barra da Tijuca',
#    'main_route': 'Avenida Ayrton Senna',
#    'main_street_number_range': '5500 - 300',
#    'lat_centroid': -22.98284615238096,
#    'lng_centroid': -43.36485640952379,
#    'label_count': 21,
#    'area_box': 0.0150864916321834,
#    'area_circle': 0.0558195085264106,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 2,
#    'events_status': 1,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2176, -22.9653233],
#      [-43.2176, -22.9636144],
#      [-43.2153, -22.9636144],
#      [-43.2153, -22.9653233],
#      [-43.2176, -22.9653233]]]},
#   'properties': {'sublabel': 23,
#    'main_neighborhood': 'Jardim Botânico',
#    'main_route': 'Rua Batista da Costa',
#    'main_street_number_range': '1952 - 120',
#    'lat_centroid': -22.964441205882355,
#    'lng_centroid': -43.2168721764706,
#    'label_count': 17,
#    'area_box': 0.0446370714385397,
#    'area_circle': 0.0436929510805269,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 1,
#    'events_status': 1,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2226, -22.9793367],
#      [-43.2226, -22.9771599],
#      [-43.2203293, -22.9771599],
#      [-43.2203293, -22.9793367],
#      [-43.2226, -22.9793367]]]},
#   'properties': {'sublabel': 24,
#    'main_neighborhood': 'Gávea',
#    'main_route': 'Rua Mario Ribeiro',
#    'main_street_number_range': '410 - 226',
#    'lat_centroid': -22.978296678947373,
#    'lng_centroid': -43.221686894736855,
#    'label_count': 19,
#    'area_box': 0.0561288609805814,
#    'area_circle': 0.0456420390558175,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.177636, -22.9162632],
#      [-43.177636, -22.9149579],
#      [-43.1751436, -22.9149579],
#      [-43.1751436, -22.9162632],
#      [-43.177636, -22.9162632]]]},
#   'properties': {'sublabel': 25,
#    'main_neighborhood': 'Centro',
#    'main_route': 'Rua Teixeira de Freitas',
#    'main_street_number_range': '840 - 182',
#    'lat_centroid': -22.91566711875,
#    'lng_centroid': -43.1762966875,
#    'label_count': 16,
#    'area_box': 0.0369600429976573,
#    'area_circle': 0.0513455600530972,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2223, -22.8968825],
#      [-43.2223, -22.89531175],
#      [-43.2214, -22.89531175],
#      [-43.2214, -22.8968825],
#      [-43.2223, -22.8968825]]]},
#   'properties': {'sublabel': 26,
#    'main_neighborhood': 'São Cristóvão',
#    'main_route': 'Rua Campo de São Cristóvão',
#    'main_street_number_range': '296 - 265',
#    'lat_centroid': -22.89616750833333,
#    'lng_centroid': -43.22179941499999,
#    'label_count': 18,
#    'area_box': 0.0160625702725528,
#    'area_circle': 0.0237647435229652,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3054, -22.8170968],
#      [-43.3054, -22.8159459],
#      [-43.3024, -22.8159459],
#      [-43.3024, -22.8170968],
#      [-43.3054, -22.8170968]]]},
#   'properties': {'sublabel': 27,
#    'main_neighborhood': 'Parada de Lucas',
#    'main_route': 'Avenida Brasil',
#    'main_street_number_range': '15001 - 14',
#    'lat_centroid': -22.81642252222223,
#    'lng_centroid': -43.30381128333333,
#    'label_count': 18,
#    'area_box': 0.0392529923483594,
#    'area_circle': 0.074497175530421,
#    'alerts': 1,
#    'alerts_status': 1,
#    'waterbag_alerts': 1,
#    'waterbag_alerts_status': 1,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3047045, -22.9996002],
#      [-43.3047045, -22.9985303],
#      [-43.30424420000001, -22.9985303],
#      [-43.30424420000001, -22.9996002],
#      [-43.3047045, -22.9996002]]]},
#   'properties': {'sublabel': 28,
#    'main_neighborhood': 'Itanhangá',
#    'main_route': 'Estrada da Barra da Tijuca',
#    'main_street_number_range': '1716 - 1636',
#    'lat_centroid': -22.998706761111112,
#    'lng_centroid': -43.30463212777778,
#    'label_count': 18,
#    'area_box': 0.0055914788000649,
#    'area_circle': 0.0110259656901168,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.208, -22.971805],
#      [-43.208, -22.9702054],
#      [-43.2060247, -22.9702054],
#      [-43.2060247, -22.971805],
#      [-43.208, -22.971805]]]},
#   'properties': {'sublabel': 29,
#    'main_neighborhood': 'Ipanema',
#    'main_route': 'Avenida Epitácio Pessoa',
#    'main_street_number_range': '4180 - 4072',
#    'lat_centroid': -22.97092306470588,
#    'lng_centroid': -43.20699601176472,
#    'label_count': 17,
#    'area_box': 0.035881876454475,
#    'area_circle': 0.0322240466385332,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2195, -22.9667395],
#      [-43.2195, -22.9653362],
#      [-43.2164, -22.9653362],
#      [-43.2164, -22.9667395],
#      [-43.2195, -22.9667395]]]},
#   'properties': {'sublabel': 30,
#    'main_neighborhood': 'Jardim Botânico',
#    'main_route': 'Rua Jardim Botânico',
#    'main_street_number_range': '1235 - 758',
#    'lat_centroid': -22.96622823076923,
#    'lng_centroid': -43.21803771538461,
#    'label_count': 13,
#    'area_box': 0.0494035891779538,
#    'area_circle': 0.0793723195265321,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2296, -22.886304],
#      [-43.2296, -22.8849444],
#      [-43.22599320000001, -22.8849444],
#      [-43.22599320000001, -22.886304],
#      [-43.2296, -22.886304]]]},
#   'properties': {'sublabel': 31,
#    'main_neighborhood': 'Caju',
#    'main_route': 'Avenida Brasil',
#    'main_street_number_range': '2996 - 498',
#    'lat_centroid': -22.88561611875,
#    'lng_centroid': -43.22779902500001,
#    'label_count': 16,
#    'area_box': 0.0557226080737553,
#    'area_circle': 0.1075727993214626,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.236, -22.9139781],
#      [-43.236, -22.9123044],
#      [-43.2326805, -22.9123044],
#      [-43.2326805, -22.9139781],
#      [-43.236, -22.9139781]]]},
#   'properties': {'sublabel': 32,
#    'main_neighborhood': 'Maracanã',
#    'main_route': 'Rua Radialista Waldir Amaral',
#    'main_street_number_range': '18 - 18',
#    'lat_centroid': -22.91319703125,
#    'lng_centroid': -43.2343259625,
#    'label_count': 16,
#    'area_box': 0.0631193340693165,
#    'area_circle': 0.0910811467464442,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2607, -22.9191499],
#      [-43.2607, -22.9170191],
#      [-43.2597827, -22.9170191],
#      [-43.2597827, -22.9191499],
#      [-43.2607, -22.9191499]]]},
#   'properties': {'sublabel': 33,
#    'main_neighborhood': 'Vila Isabel',
#    'main_route': 'Rua Alexandre Calaza',
#    'main_street_number_range': '225 - 12',
#    'lat_centroid': -22.9179375375,
#    'lng_centroid': -43.26015976250002,
#    'label_count': 16,
#    'area_box': 0.0222049971287243,
#    'area_circle': 0.0437327486053978,
#    'alerts': 2,
#    'alerts_status': 1,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2696, -22.9032958],
#      [-43.2696, -22.9019131],
#      [-43.2680694, -22.9019131],
#      [-43.2680694, -22.9032958],
#      [-43.2696, -22.9032958]]]},
#   'properties': {'sublabel': 34,
#    'main_neighborhood': 'Engenho Novo',
#    'main_route': 'Rua Silva Freire',
#    'main_street_number_range': '146 - 6',
#    'lat_centroid': -22.902698731249995,
#    'lng_centroid': -43.26870309375,
#    'label_count': 16,
#    'area_box': 0.0240455532370642,
#    'area_circle': 0.0193675050898968,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3574, -22.9625484],
#      [-43.3574, -22.9607613],
#      [-43.3565433, -22.9607613],
#      [-43.3565433, -22.9625484],
#      [-43.3574, -22.9625484]]]},
#   'properties': {'sublabel': 35,
#    'main_neighborhood': 'Gardênia Azul',
#    'main_route': 'Avenida Ayrton Senna',
#    'main_street_number_range': '5850 - 100',
#    'lat_centroid': -22.961354025,
#    'lng_centroid': -43.35678553125,
#    'label_count': 16,
#    'area_box': 0.017387520771312,
#    'area_circle': 0.0307626591342101,
#    'alerts': 1,
#    'alerts_status': 1,
#    'waterbag_alerts': 1,
#    'waterbag_alerts_status': 1,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1809, -22.9319977],
#      [-43.1809, -22.930645],
#      [-43.1773649, -22.930645],
#      [-43.1773649, -22.9319977],
#      [-43.1809, -22.9319977]]]},
#   'properties': {'sublabel': 36,
#    'main_neighborhood': 'Catete',
#    'main_route': 'Largo do Machado',
#    'main_street_number_range': '311 - 7',
#    'lat_centroid': -22.93106578,
#    'lng_centroid': -43.17920618666668,
#    'label_count': 15,
#    'area_box': 0.0543198253043071,
#    'area_circle': 0.1032691653922202,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1856678, -22.793629100000004],
#      [-43.1856678, -22.79143160000001],
#      [-43.182906, -22.79143160000001],
#      [-43.182906, -22.793629100000004],
#      [-43.1856678, -22.793629100000004]]]},
#   'properties': {'sublabel': 37,
#    'main_neighborhood': 'Tauá',
#    'main_route': 'Rua Max Yantok',
#    'main_street_number_range': '191 - 191',
#    'lat_centroid': -22.79260662666667,
#    'lng_centroid': -43.18400940000001,
#    'label_count': 15,
#    'area_box': 0.069009638330999,
#    'area_circle': 0.0631587892045704,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2159, -22.8939852],
#      [-43.2159, -22.8925726],
#      [-43.2142, -22.8925726],
#      [-43.2142, -22.8939852],
#      [-43.2159, -22.8939852]]]},
#   'properties': {'sublabel': 38,
#    'main_neighborhood': 'Caju',
#    'main_route': 'Avenida Rio de Janeiro',
#    'main_street_number_range': '1666 - 1666',
#    'lat_centroid': -22.89337942,
#    'lng_centroid': -43.21487042666666,
#    'label_count': 15,
#    'area_box': 0.0272861587913418,
#    'area_circle': 0.0238950242849491,
#    'alerts': 1,
#    'alerts_status': 1,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2334, -22.887523],
#      [-43.2334, -22.88650100000001],
#      [-43.2318166, -22.88650100000001],
#      [-43.2318166, -22.887523],
#      [-43.2334, -22.887523]]]},
#   'properties': {'sublabel': 39,
#    'main_neighborhood': 'Benfica',
#    'main_route': 'Rodovia Governador Mário Covas',
#    'main_street_number_range': '126 - 126',
#    'lat_centroid': -22.886996157142853,
#    'lng_centroid': -43.23237894285715,
#    'label_count': 14,
#    'area_box': 0.0183880389553121,
#    'area_circle': 0.0207315034739164,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1757728, -22.7937943],
#      [-43.1757728, -22.7923047],
#      [-43.1725348, -22.7923047],
#      [-43.1725348, -22.7937943],
#      [-43.1757728, -22.7937943]]]},
#   'properties': {'sublabel': 40,
#    'main_neighborhood': 'Freguesia (Ilha do Governador)',
#    'main_route': 'Rua Pio Dutra',
#    'main_street_number_range': '600 - 331',
#    'lat_centroid': -22.79292093571428,
#    'lng_centroid': -43.17436909999999,
#    'label_count': 14,
#    'area_box': 0.0548445572013421,
#    'area_circle': 0.0868159947191516,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.215055, -22.919548],
#      [-43.215055, -22.9188817],
#      [-43.213431, -22.9188817],
#      [-43.213431, -22.919548],
#      [-43.215055, -22.919548]]]},
#   'properties': {'sublabel': 41,
#    'main_neighborhood': 'Tijuca',
#    'main_route': 'Rua Haddock Lobo',
#    'main_street_number_range': '278 - 198',
#    'lat_centroid': -22.919008572727275,
#    'lng_centroid': -43.21373211818183,
#    'label_count': 11,
#    'area_box': 0.0122927468408966,
#    'area_circle': 0.0217979920956469,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3047028, -23.0037904],
#      [-43.3047028, -23.001902],
#      [-43.3036, -23.001902],
#      [-43.3036, -23.0037904],
#      [-43.3047028, -23.0037904]]]},
#   'properties': {'sublabel': 42,
#    'main_neighborhood': 'Itanhangá',
#    'main_route': 'Estrada da Barra da Tijuca',
#    'main_street_number_range': '1030 - 1014',
#    'lat_centroid': -23.003186242857147,
#    'lng_centroid': -43.30386953571429,
#    'label_count': 14,
#    'area_box': 0.0236440233780957,
#    'area_circle': 0.0343493607928497,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1859, -22.9074045],
#      [-43.1859, -22.9060259],
#      [-43.1818663, -22.9060259],
#      [-43.1818663, -22.9074045],
#      [-43.1859, -22.9074045]]]},
#   'properties': {'sublabel': 43,
#    'main_neighborhood': 'Centro',
#    'main_route': 'Rua da Constituição',
#    'main_street_number_range': '64 - 10',
#    'lat_centroid': -22.906895246153844,
#    'lng_centroid': -43.18356316153847,
#    'label_count': 13,
#    'area_box': 0.0631791975472013,
#    'area_circle': 0.1345027830644733,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.18993320000001, -22.8199816],
#      [-43.18993320000001, -22.8181279],
#      [-43.1877143, -22.8181279],
#      [-43.1877143, -22.8199816],
#      [-43.18993320000001, -22.8199816]]]},
#   'properties': {'sublabel': 44,
#    'main_neighborhood': 'Cacuia',
#    'main_route': 'Estrada da Bica',
#    'main_street_number_range': '470 - 299',
#    'lat_centroid': -22.81915535384616,
#    'lng_centroid': -43.1884146846154,
#    'label_count': 13,
#    'area_box': 0.0467609375160753,
#    'area_circle': 0.040752728568427,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2181674, -22.9187534],
#      [-43.2181674, -22.917278],
#      [-43.2171, -22.917278],
#      [-43.2171, -22.9187534],
#      [-43.2181674, -22.9187534]]]},
#   'properties': {'sublabel': 46,
#    'main_neighborhood': 'Tijuca',
#    'main_route': 'Rua Doutor Satamini',
#    'main_street_number_range': '161 - 156',
#    'lat_centroid': -22.91813383076923,
#    'lng_centroid': -43.21774827692308,
#    'label_count': 13,
#    'area_box': 0.0178909677470703,
#    'area_circle': 0.0209672246370969,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3345624, -22.8668979],
#      [-43.3345624, -22.8660996],
#      [-43.3343, -22.8660996],
#      [-43.3343, -22.8668979],
#      [-43.3345624, -22.8668979]]]},
#   'properties': {'sublabel': 47,
#    'main_neighborhood': 'Madureira',
#    'main_route': 'Avenida Ministro Edgard Romero',
#    'main_street_number_range': '492 - 244',
#    'lat_centroid': -22.866227007692306,
#    'lng_centroid': -43.33436719230769,
#    'label_count': 13,
#    'area_box': 0.0023806083480538,
#    'area_circle': 0.006138298754485,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3669, -22.9978325],
#      [-43.3669, -22.9970898],
#      [-43.3645, -22.9970898],
#      [-43.3645, -22.9978325],
#      [-43.3669, -22.9978325]]]},
#   'properties': {'sublabel': 48,
#    'main_neighborhood': 'Barra da Tijuca',
#    'main_route': 'Avenida Ayrton Senna',
#    'main_street_number_range': '100 - 100',
#    'lat_centroid': -22.99764047692308,
#    'lng_centroid': -43.36625035384616,
#    'label_count': 13,
#    'area_box': 0.0202382161190218,
#    'area_circle': 0.0475518357531589,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.6034432, -22.9145304],
#      [-43.6034432, -22.913977],
#      [-43.6001, -22.913977],
#      [-43.6001, -22.9145304],
#      [-43.6034432, -22.9145304]]]},
#   'properties': {'sublabel': 49,
#    'main_neighborhood': 'Inhoaíba',
#    'main_route': 'Avenida Cesário de Melo',
#    'main_street_number_range': '7671 - 3',
#    'lat_centroid': -22.91434289230769,
#    'lng_centroid': -43.6020961,
#    'label_count': 13,
#    'area_box': 0.0210189079797872,
#    'area_circle': 0.0923848530132052,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1900588, -22.9536329],
#      [-43.1900588, -22.9529156],
#      [-43.1883972, -22.9529156],
#      [-43.1883972, -22.9536329],
#      [-43.1900588, -22.9536329]]]},
#   'properties': {'sublabel': 50,
#    'main_neighborhood': 'Botafogo',
#    'main_route': 'Rua Voluntários da Pátria',
#    'main_street_number_range': '236 - 201',
#    'lat_centroid': -22.953312436363635,
#    'lng_centroid': -43.18930575454545,
#    'label_count': 11,
#    'area_box': 0.0135367264112289,
#    'area_circle': 0.022807629938892,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.311421, -22.995249],
#      [-43.311421, -22.9952425],
#      [-43.3113, -22.9952425],
#      [-43.3113, -22.995249],
#      [-43.311421, -22.995249]]]},
#   'properties': {'sublabel': 51,
#    'main_neighborhood': 'Itanhangá',
#    'main_route': 'Estrada do Itanhangá',
#    'main_street_number_range': '2260 - 2260',
#    'lat_centroid': -22.99524358333333,
#    'lng_centroid': -43.31133110000001,
#    'label_count': 12,
#    'area_box': 8.930036938088321e-06,
#    'area_circle': 0.0001208731158305,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3239242, -22.9892218],
#      [-43.3239242, -22.98838],
#      [-43.3223, -22.98838],
#      [-43.3223, -22.9892218],
#      [-43.3239242, -22.9892218]]]},
#   'properties': {'sublabel': 52,
#    'main_neighborhood': 'Itanhangá',
#    'main_route': 'Avenida Engenheiro Souza Filho',
#    'main_street_number_range': '613 - 377',
#    'lat_centroid': -22.988833381818186,
#    'lng_centroid': -43.32322827272728,
#    'label_count': 11,
#    'area_box': 0.0155246998817911,
#    'area_circle': 0.0217810699468995,
#    'alerts': 1,
#    'alerts_status': 1,
#    'waterbag_alerts': 1,
#    'waterbag_alerts_status': 1,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3894, -22.8992071],
#      [-43.3894, -22.898978],
#      [-43.3889645, -22.898978],
#      [-43.3889645, -22.8992071],
#      [-43.3894, -22.8992071]]]},
#   'properties': {'sublabel': 53,
#    'main_neighborhood': 'Jardim Sulacap',
#    'main_route': 'Estrada do Catonho',
#    'main_street_number_range': '977 - 965',
#    'lat_centroid': -22.89899960833333,
#    'lng_centroid': -43.38912901666666,
#    'label_count': 12,
#    'area_box': 0.0011336248037559,
#    'area_circle': 0.0015680104104509,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.178, -22.9143489],
#      [-43.178, -22.9123948],
#      [-43.1743, -22.9123948],
#      [-43.1743, -22.9143489],
#      [-43.178, -22.9143489]]]},
#   'properties': {'sublabel': 54,
#    'main_neighborhood': 'Centro',
#    'main_route': 'Rua do Passeio',
#    'main_street_number_range': '52 - 39',
#    'lat_centroid': -22.91340753636364,
#    'lng_centroid': -43.17645859090909,
#    'label_count': 11,
#    'area_box': 0.0821409849061954,
#    'area_circle': 0.113157963487291,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1788, -22.9247315],
#      [-43.1788, -22.9234676],
#      [-43.1767665, -22.9234676],
#      [-43.1767665, -22.9247315],
#      [-43.1788, -22.9247315]]]},
#   'properties': {'sublabel': 55,
#    'main_neighborhood': 'Catete',
#    'main_route': 'Rua do Catete',
#    'main_street_number_range': '111 - 68',
#    'lat_centroid': -22.92394414545455,
#    'lng_centroid': -43.17745909999999,
#    'label_count': 11,
#    'area_box': 0.0291967619919028,
#    'area_circle': 0.0341744598655848,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1828, -22.9428485],
#      [-43.1828, -22.94132],
#      [-43.179, -22.94132],
#      [-43.179, -22.9428485],
#      [-43.1828, -22.9428485]]]},
#   'properties': {'sublabel': 56,
#    'main_neighborhood': 'Botafogo',
#    'main_route': 'Praia de Botafogo',
#    'main_street_number_range': '2280 - 190',
#    'lat_centroid': -22.94184376,
#    'lng_centroid': -43.18060991,
#    'label_count': 10,
#    'area_box': 0.0659736439947774,
#    'area_circle': 0.1193069655179368,
#    'alerts': 3,
#    'alerts_status': 1,
#    'waterbag_alerts': 2,
#    'waterbag_alerts_status': 1,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1858481, -22.9444059],
#      [-43.1858481, -22.9427518],
#      [-43.1826, -22.9427518],
#      [-43.1826, -22.9444059],
#      [-43.1858481, -22.9444059]]]},
#   'properties': {'sublabel': 57,
#    'main_neighborhood': 'Botafogo',
#    'main_route': 'Rua Marquês de Olinda',
#    'main_street_number_range': '108 - 11',
#    'lat_centroid': -22.94378064444444,
#    'lng_centroid': -43.18385301111112,
#    'label_count': 9,
#    'area_box': 0.0610250156689706,
#    'area_circle': 0.0871661477792975,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2015, -22.9029391],
#      [-43.2015, -22.9013982],
#      [-43.1991, -22.9013982],
#      [-43.1991, -22.9029391],
#      [-43.2015, -22.9029391]]]},
#   'properties': {'sublabel': 58,
#    'main_neighborhood': 'Santo Cristo',
#    'main_route': 'Rua da América',
#    'main_street_number_range': '141 - 21',
#    'lat_centroid': -22.90224885454545,
#    'lng_centroid': -43.19978181818182,
#    'label_count': 11,
#    'area_box': 0.0420176890285936,
#    'area_circle': 0.0476184790082702,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2049972, -22.9834143],
#      [-43.2049972, -22.9818486],
#      [-43.2027195, -22.9818486],
#      [-43.2027195, -22.9834143],
#      [-43.2049972, -22.9834143]]]},
#   'properties': {'sublabel': 59,
#    'main_neighborhood': 'Ipanema',
#    'main_route': 'Rua Vinícius de Moraes',
#    'main_street_number_range': '201 - 98',
#    'lat_centroid': -22.983073899999997,
#    'lng_centroid': -43.20300897272728,
#    'label_count': 11,
#    'area_box': 0.0404947987250558,
#    'area_circle': 0.0428383453934556,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2087197, -22.9810568],
#      [-43.2087197, -22.98053710000001],
#      [-43.205, -22.98053710000001],
#      [-43.205, -22.9810568],
#      [-43.2087197, -22.9810568]]]},
#   'properties': {'sublabel': 60,
#    'main_neighborhood': 'Ipanema',
#    'main_route': 'Avenida Epitácio Pessoa',
#    'main_street_number_range': '1274 - 1084',
#    'lat_centroid': -22.98085909090909,
#    'lng_centroid': -43.20703900909091,
#    'label_count': 11,
#    'area_box': 0.0219513162218415,
#    'area_circle': 0.1142528918676618,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2098, -22.9005424],
#      [-43.2098, -22.8990496],
#      [-43.2068, -22.8990496],
#      [-43.2068, -22.9005424],
#      [-43.2098, -22.9005424]]]},
#   'properties': {'sublabel': 61,
#    'main_neighborhood': 'Santo Cristo',
#    'main_route': 'Avenida Francisco Bicalho',
#    'main_street_number_range': '241 - 1',
#    'lat_centroid': -22.90000273333333,
#    'lng_centroid': -43.20870993333333,
#    'label_count': 9,
#    'area_box': 0.0508834759596689,
#    'area_circle': 0.074406461836351,
#    'alerts': 1,
#    'alerts_status': 1,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2224084, -22.913357],
#      [-43.2224084, -22.9120148],
#      [-43.2205729, -22.9120148],
#      [-43.2205729, -22.913357],
#      [-43.2224084, -22.913357]]]},
#   'properties': {'sublabel': 62,
#    'main_neighborhood': 'Maracanã',
#    'main_route': 'Rua Morais e Silva',
#    'main_street_number_range': '526 - 15',
#    'lat_centroid': -22.912690827272726,
#    'lng_centroid': -43.22161657272727,
#    'label_count': 11,
#    'area_box': 0.0279888573183331,
#    'area_circle': 0.0278480521022022,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2276, -22.8126375],
#      [-43.2276, -22.8120658],
#      [-43.2261178, -22.8120658],
#      [-43.2261178, -22.8126375],
#      [-43.2276, -22.8126375]]]},
#   'properties': {'sublabel': 63,
#    'main_neighborhood': 'Galeão',
#    'main_route': 'Estrada das Canárias',
#    'main_street_number_range': '953 - 795',
#    'lat_centroid': -22.81254105454545,
#    'lng_centroid': -43.22729117272728,
#    'label_count': 11,
#    'area_box': 0.0096338952176696,
#    'area_circle': 0.0181860070365995,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2455451, -22.875704],
#      [-43.2455451, -22.8742644],
#      [-43.2425775, -22.8742644],
#      [-43.2425775, -22.875704],
#      [-43.2455451, -22.875704]]]},
#   'properties': {'sublabel': 64,
#    'main_neighborhood': 'Manguinhos',
#    'main_route': 'Avenida Brasil',
#    'main_street_number_range': '5000 - 5000',
#    'lat_centroid': -22.875335354545456,
#    'lng_centroid': -43.24347007272727,
#    'label_count': 11,
#    'area_box': 0.0485488200874794,
#    'area_circle': 0.0728344350900531,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.24800000000001, -22.8639104],
#      [-43.24800000000001, -22.8624862],
#      [-43.2476, -22.8624862],
#      [-43.2476, -22.8639104],
#      [-43.24800000000001, -22.8639104]]]},
#   'properties': {'sublabel': 65,
#    'main_neighborhood': 'Manguinhos',
#    'main_route': 'Avenida Brasil',
#    'main_street_number_range': '5622 - 4036',
#    'lat_centroid': -22.86296217272727,
#    'lng_centroid': -43.24771942727273,
#    'label_count': 11,
#    'area_box': 0.0064743962288426,
#    'area_circle': 0.0195369770428158,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1729, -22.9075392],
#      [-43.1729, -22.9064751],
#      [-43.1712318, -22.9064751],
#      [-43.1712318, -22.9075392],
#      [-43.1729, -22.9075392]]]},
#   'properties': {'sublabel': 66,
#    'main_neighborhood': 'Centro',
#    'main_route': 'Avenida Almirante Barroso',
#    'main_street_number_range': '472 - 472',
#    'lat_centroid': -22.90687879,
#    'lng_centroid': -43.17270318,
#    'label_count': 10,
#    'area_box': 0.0201679558752899,
#    'area_circle': 0.0230047996107396,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1849282, -22.905214800000003],
#      [-43.1849282, -22.9039308],
#      [-43.1816902, -22.9039308],
#      [-43.1816902, -22.905214800000003],
#      [-43.1849282, -22.905214800000003]]]},
#   'properties': {'sublabel': 68,
#    'main_neighborhood': 'Centro',
#    'main_route': 'Avenida Passos',
#    'main_street_number_range': '80 - 40',
#    'lat_centroid': -22.90451412,
#    'lng_centroid': -43.18319102,
#    'label_count': 10,
#    'area_box': 0.0472368370596184,
#    'area_circle': 0.0866745138314743,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1961, -22.9146397],
#      [-43.1961, -22.9128425],
#      [-43.1946, -22.9128425],
#      [-43.1946, -22.9146397],
#      [-43.1961, -22.9146397]]]},
#   'properties': {'sublabel': 69,
#    'main_neighborhood': 'Cidade Nova',
#    'main_route': 'Rua Frei Caneca',
#    'main_street_number_range': '125 - 8',
#    'lat_centroid': -22.913620280000004,
#    'lng_centroid': -43.19522,
#    'label_count': 10,
#    'area_box': 0.0306265381890086,
#    'area_circle': 0.0311109836419175,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2207, -22.891847100000003],
#      [-43.2207, -22.8899818],
#      [-43.2168, -22.8899818],
#      [-43.2168, -22.891847100000003],
#      [-43.2207, -22.891847100000003]]]},
#   'properties': {'sublabel': 70,
#    'main_neighborhood': 'São Cristóvão',
#    'main_route': 'Rua Conde de Leopoldina',
#    'main_street_number_range': '468 - 307',
#    'lat_centroid': -22.890989640000004,
#    'lng_centroid': -43.2191151,
#    'label_count': 10,
#    'area_box': 0.0826599183011031,
#    'area_circle': 0.1257632919681354,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.24113010000001, -22.9326711],
#      [-43.24113010000001, -22.9320902],
#      [-43.2401, -22.9320902],
#      [-43.2401, -22.9326711],
#      [-43.24113010000001, -22.9326711]]]},
#   'properties': {'sublabel': 71,
#    'main_neighborhood': 'Tijuca',
#    'main_route': 'Rua Conde de Bonfim',
#    'main_street_number_range': '711 - 681',
#    'lat_centroid': -22.93227957,
#    'lng_centroid': -43.24049197999999,
#    'label_count': 10,
#    'area_box': 0.0067972401636062,
#    'area_circle': 0.0087683783098051,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2521323, -22.91956960000001],
#      [-43.2521323, -22.9184206],
#      [-43.2500594, -22.9184206],
#      [-43.2500594, -22.91956960000001],
#      [-43.2521323, -22.91956960000001]]]},
#   'properties': {'sublabel': 72,
#    'main_neighborhood': 'Vila Isabel',
#    'main_route': 'Rua Teodoro da Silva',
#    'main_street_number_range': '696 - 606',
#    'lat_centroid': -22.918726470000006,
#    'lng_centroid': -43.25071026,
#    'label_count': 10,
#    'area_box': 0.0270577804209637,
#    'area_circle': 0.0355142415774364,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2619311, -22.9022738],
#      [-43.2619311, -22.9021825],
#      [-43.2586439, -22.9021825],
#      [-43.2586439, -22.9022738],
#      [-43.2619311, -22.9022738]]]},
#   'properties': {'sublabel': 73,
#    'main_neighborhood': 'Sampaio',
#    'main_route': 'Rua Antunes García',
#    'main_street_number_range': '11 - 11',
#    'lat_centroid': -22.902204544444448,
#    'lng_centroid': -43.260851311111104,
#    'label_count': 9,
#    'area_box': 0.0034099121100106,
#    'area_circle': 0.0893315590589499,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.3302, -22.823801100000004],
#      [-43.3302, -22.82304],
#      [-43.3279, -22.82304],
#      [-43.3279, -22.823801100000004],
#      [-43.3302, -22.823801100000004]]]},
#   'properties': {'sublabel': 74,
#    'main_neighborhood': 'Irajá',
#    'main_route': 'Avenida Brasil',
#    'main_street_number_range': '19001 - 17385',
#    'lat_centroid': -22.823261979999995,
#    'lng_centroid': -43.32856420000002,
#    'label_count': 10,
#    'area_box': 0.0199004079638848,
#    'area_circle': 0.0437833726052148,
#    'alerts': 1,
#    'alerts_status': 1,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.353265500000006, -22.8990269],
#      [-43.353265500000006, -22.8982639],
#      [-43.3523871, -22.8982639],
#      [-43.3523871, -22.8990269],
#      [-43.353265500000006, -22.8990269]]]},
#   'properties': {'sublabel': 75,
#    'main_neighborhood': 'Praça Seca',
#    'main_route': 'Rua Cândido Benício',
#    'main_street_number_range': '2045 - 1',
#    'lat_centroid': -22.89873496,
#    'lng_centroid': -43.35290550000001,
#    'label_count': 10,
#    'area_box': 0.0076150779862499,
#    'area_circle': 0.0063791104872527,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.4726, -22.880398],
#      [-43.4726, -22.8801501],
#      [-43.4700107, -22.8801501],
#      [-43.4700107, -22.880398],
#      [-43.4726, -22.880398]]]},
#   'properties': {'sublabel': 76,
#    'main_neighborhood': 'Bangu',
#    'main_route': 'Rua da Feira',
#    'main_street_number_range': '540 - 359',
#    'lat_centroid': -22.880275290000004,
#    'lng_centroid': -43.47223909,
#    'label_count': 10,
#    'area_box': 0.0072941357761401,
#    'area_circle': 0.0554443285812863,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.1971, -22.8050856],
#      [-43.1971, -22.804934],
#      [-43.1967904, -22.804934],
#      [-43.1967904, -22.8050856],
#      [-43.1971, -22.8050856]]]},
#   'properties': {'sublabel': 77,
#    'main_neighborhood': 'Jardim Carioca',
#    'main_route': 'Rua Muiatuca',
#    'main_street_number_range': '74 - 73',
#    'lat_centroid': -22.80501158888889,
#    'lng_centroid': -43.19683697777778,
#    'label_count': 9,
#    'area_box': 0.0005336419232438,
#    'area_circle': 0.0007935461349489,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.2046, -22.973107100000004],
#      [-43.2046, -22.9722932],
#      [-43.2019981, -22.9722932],
#      [-43.2019981, -22.973107100000004],
#      [-43.2046, -22.973107100000004]]]},
#   'properties': {'sublabel': 78,
#    'main_neighborhood': 'Lagoa',
#    'main_route': 'Avenida Epitácio Pessoa',
#    'main_street_number_range': '3000 - 1015',
#    'lat_centroid': -22.97256154444444,
#    'lng_centroid': -43.20359403333334,
#    'label_count': 9,
#    'area_box': 0.02404844583301,
#    'area_circle': 0.0559093344065634,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.4587, -22.8803198],
#      [-43.4587, -22.8792914],
#      [-43.4547, -22.8792914],
#      [-43.4547, -22.8803198],
#      [-43.4587, -22.8803198]]]},
#   'properties': {'sublabel': 81,
#    'main_neighborhood': 'Bangu',
#    'main_route': 'Rua Francisco Real',
#    'main_street_number_range': '1365 - 974',
#    'lat_centroid': -22.87963754444444,
#    'lng_centroid': -43.45676805555557,
#    'label_count': 9,
#    'area_box': 0.0467453556927194,
#    'area_circle': 0.1323169094631387,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-43.6479, -22.9686009],
#      [-43.6479, -22.968175],
#      [-43.6478602, -22.968175],
#      [-43.6478602, -22.9686009],
#      [-43.6479, -22.9686009]]]},
#   'properties': {'sublabel': 82,
#    'main_neighborhood': 'Guaratiba',
#    'main_route': 'Estrada da Pedra',
#    'main_street_number_range': '5726 - 5291',
#    'lat_centroid': -22.96826964444445,
#    'lng_centroid': -43.64787788888889,
#    'label_count': 9,
#    'area_box': 0.0001924995049206,
#    'area_circle': 0.0017471982297003,
#    'alerts': 0,
#    'alerts_status': 0,
#    'waterbag_alerts': 0,
#    'waterbag_alerts_status': 0,
#    'events': 0,
#    'events_status': 0,
#    'waterbag_events': 0,
#    'waterbag_events_status': 0}}]
