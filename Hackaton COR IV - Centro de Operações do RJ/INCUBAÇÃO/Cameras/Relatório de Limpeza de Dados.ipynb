# %% [markdown]
# # City camera images data cleaning report
# ---

# %% [markdown]
# ## Original Cloud Storage bucket: city-cameras-images

# %% [markdown]
# Number of objects: 1000 k -> 500 k
#
# Number of bytes: 80GB -> 60GB

# %% [markdown]
# #### Number of objects after data cleaning

# %% [markdown]
# ![image.png](attachment:49189394-b435-4407-8dcc-f18b04a07e60.png)

# %% [markdown]
# #### Number of bytes after data cleaning

# %% [markdown]
# ![image.png](attachment:ae1910db-18f9-4c98-b707-acb74a03dc27.png)

# %% [markdown]
# ---
# ## New Cloud Storage bucket: flood-video-collection

# %% [markdown]
# Number of objects: 500 k -> 30 k  ( 6% )
#
# Number of bytes: 60GB -> 20GB  ( 33,3% )

# %% [markdown]
# #### Number of bytes after transfers and image-to-video conversions

# %% [markdown]
# New bucket size: 20Gb

# %% [markdown]
# ![image.png](attachment:1f696fca-2dc5-459a-88e7-586eb780f8cc.png)

# %% [markdown]
# #### Number of objects after transfers and image-to-video conversions

# %% [markdown]
# New bucket objcts: 30k

# %% [markdown]
# New bucket objects: 30k (33,3%)

# %% [markdown]
# ![image.png](attachment:89d9d1e1-beed-4134-8f99-2199dbd00351.png)
