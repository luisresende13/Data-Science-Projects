# %% [markdown]
# # Relatório: custo/processamento de stream e gravação de câmeras

# %% [markdown]
# #### Relatório de custos

# %% [markdown]
# ![image.png](attachment:80e2a594-428a-4c4f-bae8-b88d460d1434.png)

# %% [markdown]
# #### Contagem e latências de solicitação

# %% [markdown]
# ![image.png](attachment:7c28640e-52ff-44fa-b2cd-8b24f007a19b.png)

# %% [markdown]
# #### Instâncias e uso da CPU do contêiner

# %% [markdown]
# ![image.png](attachment:c41f5647-169c-4e1e-b135-2e7d04088de2.png)

# %% [markdown]
# #### Uso de memória do container e tempo de instância faturável

# %% [markdown]
# ![image.png](attachment:1dfb73d6-6fa9-4e86-959d-daa644bbb260.png)![image.png](attachment:00fa139e-e5d5-44cb-bd06-b9d547cdd475.png)

# %% [markdown]
# #### Bytes recebidos e enviados

# %% [markdown]
# ![image.png](attachment:3661052f-dc1e-462c-9e1d-13c652ce2bdc.png)

# %% [markdown]
# #### Máximo de solicitações simultâneas

# %% [markdown]
# ![image.png](attachment:6ae93af3-9799-46f9-a3ef-0ee559ae35eb.png)
