# %%
import super_gradients
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import super_gradients
#
# ModuleNotFoundError: No module named 'super_gradients'

# %%
# !pip install super-gradients
# Out:
# ...
#      -------------------------------------- 983.2/983.2 kB 1.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.9/2.9 MB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.8/2.8 MB 1.9 MB/s eta 0:00:00
# ...
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 408.6/408.6 kB 1.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 53.2/53.2 kB 913.7 kB/s eta 0:00:00
# ...
#      -------------------------------------- 135.6/135.6 kB 2.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 79.5/79.5 kB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 68.0/68.0 kB 284.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.8/1.8 MB 1.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
import torch
