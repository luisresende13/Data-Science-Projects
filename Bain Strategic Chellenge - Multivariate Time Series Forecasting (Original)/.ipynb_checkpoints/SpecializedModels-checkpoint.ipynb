# %%
import os
import pandas as pd; pd.set_option('display.max_columns', None) 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import pickle
from IPython.display import clear_output as co
from random import random
import warnings; # ...

import sklearn.preprocessing
import sklearn.model_selection
import sklearn.metrics
import sklearn.utils

# %%
le = sklearn.preprocessing.LabelEncoder
#regressors = dict(sklearn.utils.all_estimators('regressor'))
metrics = sklearn.metrics._regression
mae = metrics.mean_absolute_error
mse = metrics.mean_squared_error
mape = metrics.mean_absolute_percentage_error
r2 = metrics.r2_score
me = metrics.max_error
medae = metrics.median_absolute_error
evs = metrics.explained_variance_score
mpd = metrics.mean_poisson_deviance
mgd = metrics.mean_gamma_deviance
def wape(ye, yhat):
    return np.abs(ye-yhat).sum()/ye.sum()
def e(ye, yhat):
    return np.abs(yhat-ye).sum()
def estd(ye, yhat):
    return np.abs(yhat-ye).std()

# %% [markdown]
# ### Declarando Funções

# %%
def load_series(path='series/'):
    filenames = os.listdir(path)
    series, cnt, n_files = {}, 0, len(filenames)
    freq = range(1, n_files, 10)
    for filename in filenames:
        cnt+=1
        if cnt in freq: print(f'Files loaded: {cnt}/{n_files}'); co(wait=True)
        series[filename[:-4]] = pd.read_csv(path+filename, index_col=0)
    print(f'Done! Loaded {n_files} files.')
    return series

## Return random serie's city and product-type
def sample_serie():
    keys = np.random.choice(list(series.keys())).split('-')
    return keys[0], keys[1:]
    
def clean_series(series, train_min=5):
    clean_series = {}
    test_empty = []
    excluded_test_index = []
    n_total = len(series)
    n_values_total = 0
    n_values_test = 0
    n_values_train = 0
    n_series = 0
    n_series_empty = 0
    n_series_test_empty = 0
    n_series_train_min_empty = 0
    n_values = 0
    n_test_empty_total = 0
    n_train_empty_total = 0
    n_non_empty_values = 0
    
    cnt, freq = 0, range(1, n_total, 10)
    for key in list(series.keys()):
        cnt+=1
        if cnt in freq: print(f'Cleaned series: {cnt}/{n_total}'); co(wait=True)
        
        msk = series[key]['year'].isin(['01/01/2016', '01/01/2017'])
        test = series[key][msk]
        train = series[key][msk==False]

        n = len(series[key])
        n_empty = series[key][target].isna().sum()
        n_test_empty = test[target].isna().sum()
        n_train_empty = train[target].isna().sum()

        cond1 = n_test_empty == len(test)
        cond2 = n_train_empty > (len(train) - train_min) # if number of training samples is greater than specified minimum.
        
        n_values_total += n
        n_values_test += len(test)
        n_values_train += len(train)

        n_series_empty += n==n_empty
        n_test_empty_total+=n_test_empty
        n_train_empty_total+=n_train_empty
        n_series_test_empty += cond1
        n_series_train_min_empty += cond2

        if cond1 or cond2:
            n_series+=1
            n_values+=len(series[key])
            n_non_empty_values+=(len(series[key]) - n_empty)
            excluded_test_index.extend(test[test[target].isna()==False].index.tolist())

        else:
            n_values+=n_empty
            clean_series[key] = series[key].dropna(subset=['area'])
    
    print('Values Count:')
    print( pd.Series(
        [n_total, n_values_total, n_values_test, n_values_train],
        index=['n_total', 'n_values_total', 'n_values_test', 'n_values_train'])
    )
    print(); print('Excluded count:')
    print(
        pd.Series([
            n_series, n_series_empty, n_series_test_empty, n_series_train_min_empty,
            n_values, n_values-n_non_empty_values, n_test_empty_total, n_train_empty_total,
            n_non_empty_values, len(excluded_test_index)
        ],
        index=[
            'series', 'series_empty', 'series_test_empty', f'series_train_min_<_{train_min}',
            'values', 'values_empty', 'test_empty', 'train_empty',
            'non_empty_values', 'non_empty_test_values'
        ])
    )
    return clean_series, excluded_test_index

def test_data():
    Y_e = []
    for key in series.keys():
        x_t, x_e, y_t, y_e = custom_tts(key)
        Y_e.append(y_e)
    return pd.concat(Y_e)

def get_prod_indexes():
    prod_indexes = {}
    for prod in prods:
        if prod not in ['Sorghum', 'Açaí']:
            if '-' in prod: 
                product, prod_type = prod.split('-')
            else:
                product = prod
            df = data_e[data_e['product']==product].copy()        
            if '-' in prod: 
                df = df[df['product_type']==prod_type]

            prod_indexes[prod] = df.index.copy()
    return prod_indexes

def get_prodtype_indexes():
    prodtype_indexes = {}
    for prodtype in ['temporary', 'permanent', 'pasture']:
        df = data_e[data_e['product_type']==prodtype].copy()        
        prodtype_indexes[prodtype] = df.index.copy()
    return prodtype_indexes

#### Mapping between the series test indexes and the series key
def get_key_index_test_map():    
    key_test_index_map = {}
    for key in series.keys():    
        key_index = series[key].index
        for entry_index in key_index:
            if entry_index in Y_e.index:
                key_test_index_map[entry_index] = key
    return key_test_index_map

def get_key_prodtype_map():
    key_prodtype_map = {}
    for key in series.keys():
        key_prodtype_map[key] = series[key].iloc[0]['product_type']
    return key_prodtype_map

#### Extract predictive and target variables
def get_xy(data, target='area', fill_na=0):
    ## 1. Extraindo variáveis preditivas
    X = data.drop(target, 1)
    ## 2. Extraindo Variável Álvo
    Y = data[target].copy()
    #### Substituição de Valores Vazios para Variável Alvo
#     Y[Y.isna()] = fill_na
    return X,Y

#### Label Encode pandas dataframe
def label_encode(X, base=None):
    if type(base)==type(None): base = X
    X_lab = X.copy()
    for column in X:
        X_lab[column] = le().fit(base[column]).transform(X[column])
    return X_lab

## Separação das amostras para treinamento e teste
def split_ts(x, y, col='year', horizon=2):
#     periods = x[col].sort_values().iloc[:len(x)-horizon]
    msk = x[col].isin([42, 43])
    return [x[msk==False], x[msk], y[msk==False], y[msk]]

### Train test split of time series by key
def custom_tts(key, encode=True):
    x, y = get_xy(series[key], target='area', fill_na=0)
    if encode: x = label_encode(x[['year']], base=data)
    return split_ts(x, y, col='year', horizon=2)

## Evaluating Model Predictions
def score_predictions(y_e, y_hat):
    return [mae(y_e, y_hat), mse(y_e, y_hat), mape(y_e, y_hat), wape(y_e, y_hat), r2(y_e, y_hat)]

## Evaluating model predictions given scorer list
def score_predictions_custom(y_e, y_hat, scorers=None):
    if type(scorers)==type(None):
        scorers = [mae, mse, mape, wape, r2]; names=scrs
    return [scorer(y_e, y_hat) for scorer in scorers]

## Evaluating model predictions given scorer list
def score_predictions_fancy(y_e, y_hat, model_name='', scorers=None, names=None):
    if type(scorers)==type(None):
        scorers = [mae, mse, mape, wape, r2]; names=scrs
    scores = [scorer(y_e, y_hat) for scorer in scorers]
    return pd.Series(scores, name=model_name, index=names)

def isComplete(ts):
    return (ts.index.max().year - ts.index.min().year + 1) == len(ts)

# %% [markdown]
# ---
# ### 1. Loading data

# %%
target = 'area'
prodtypes = ['permanent', 'temporary', 'pasture']
prods = [
    'Rice', 'Beans', 'Cassava',
    'Corn', 'Soy', 'Sorghum',
    'Cocoa', 'Palm oil', 'Açaí',
    'Livestock', 'Others-temporary', 'Others-permanent'
]

# %%
data = pd.read_csv('data/historical-database-clean.csv')
raw_series = load_series()
# Out:
# Done! Loaded 1712 files.

# %% [markdown]
# ---
# ## 2. Processing data

# %% [markdown]
# ### 2.0 Dealing with missing values:
#
# * Excluindo séries para as quais a variável alvo está vazia para 2016 e 2017.
# * Excluindo séries para as quais a variável alvo tem menos que "n=1" entradas no conjunto de treinamento (35 found).
# * Excluindo entradas vazias.

# %%
series, excluded_test_index = clean_series(raw_series, train_min=1)
keys = list(series.keys())
# Out:
# Values Count:
# n_total            1712
# n_values_total    73744
# n_values_test      3424
# n_values_train    70320
# dtype: int64
#
# Excluded count:
# series                     605
# series_empty               442
# series_test_empty          582
# series_train_min_<_1       465
# values                   40936
# values_empty             39035
# test_empty                1198
# train_empty              37837
# non_empty_values          1901
# non_empty_test_values       35
# dtype: int64

# %% [markdown]
# #### Setting pandas datetime index

# %%
dt_series = {}
for key in keys:
    dt_series[key] = series[key].set_index(pd.DatetimeIndex(series[key]['year'].astype('datetime64[Y]')))[target]

# %% [markdown]
# #### Setting integer year index

# %%
int_series = {}
for key in keys:
    int_series[key] = series[key].set_index(pd.DatetimeIndex(series[key]['year'].astype('datetime64[Y]')).year)[target]

# %% [markdown]
# #### Setting label encoded index

# %%
LE = le().fit(data['year'])
lab_series = {}
for key in keys:
    lab_series[key] = series[key].set_index(LE.transform(series[key]['year']))[target]

# %% [markdown]
# #### Settings train and test series

# %%
tt_series = {}
for key in keys:
    tt_series[key] = {'train': dt_series[key][:'2015'].copy(), 'test': dt_series[key]['2016':].copy()}

# %%
tt_lab_series = {}
for key in keys:
    msk = lab_series[key].index.isin([42, 43])
    tt_lab_series[key] = {'train': lab_series[key][msk==False].copy(), 'test': lab_series[key][msk].copy()}

# %% [markdown]
# #### Extracting complete time series

# %%
full_tt_series = {}
for key in keys:
    if len(tt_lab_series[key]['train'])==42 and len(tt_lab_series[key]['test'])==2:        
        full_tt_series[key] = tt_lab_series[key]
full_keys = list(full_tt_series.keys())

# %% [markdown]
# #### Concating full time series

# %%
X = pd.concat([lab_series[key] for key in full_keys], 1); X.columns = full_keys

# %% [markdown]
# ### 2.1 Extracting test data (2016 and 2017)

# %%
Y_e = test_data()
data_e = data.loc[Y_e.index].copy()

#### Extracting test index for each type-product combination
prod_indexes = get_prod_indexes()
#### Extracting test index for each product_type
prodtype_indexes = get_prodtype_indexes()
#### Mapping between the series test indexes and the series key
key_test_index_map = get_key_index_test_map()
#### Mapping between series keys and product type
key_prodtype_map = get_key_prodtype_map()

# %% [markdown]
# ---
# ## Comparing specialized models

# %% [markdown]
# #### Metric criteria settings

# %%
criteria_map = {'e': 0, 'estd': 0, 'max_error': 0, 'mae': 0, 'mse': 0, 'medae': 0, 'mape': 0, 'wape': 0, 'r2': -1, 'evs': -1}
scorers_names = ['e','estd','max_error','mae','mse','medae','mape','wape','r2','evs']
scorers = [e, estd, me, mae, mse, medae, mape, wape, r2, evs]
scrs = ['mae', 'mse', 'mape', 'wape', 'r2']
sel_scrs = scorers_names #scrs

# %% [markdown]
# ts_models_scrs, models_scrs, models_prod_scrs, models_prediction = (models) => save_models=True, save_scores=True, scorers=scorers, scorers_names=scorers_names)

# %%
def train_test_min_max_year(train, test):
    return train.index.min().year, train.index.max().year, test.index.min().year, test.index.max().year

def train_test_min_max(train, test):
    return train.index.min(), train.index.max(), test.index.min(), test.index.max()

# contrived train and test datasets
train = full_tt_series[full_keys[0]]['train']
test = full_tt_series[full_keys[0]]['test']

# train and test prediction intervals
x_train_min, x_train_max, x_test_min, x_test_max = train_test_min_max(train, test)
# x_train_min_year, x_train_max_year, x_test_min_year, x_test_max_year = train_test_min_max_year(train, test)

# %%
x_train_min, x_train_max, x_test_min, x_test_max
# Out:
# (0, 41, 42, 43)

# %% [markdown]
# ### AR example

# %%
from statsmodels.tsa.ar_model import AutoReg
from random import random
# contrived dataset
# fit model
model = AutoReg(train, lags=1)
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(x_test_min, x_test_max)
print(yhat)
# Out:
# 42    57.129677
# 43    52.160171
# dtype: float64

# %%
test
# Out:
# 42    67.0
# 43    76.0
# Name: area, dtype: float64

# %% [markdown]
# ## ARIMA example

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
# fit model
model = ARIMA(train, order=(1, 1, 1))
model_fit = model.fit()

# make prediction
yhat_test = model_fit.predict(x_test_min, x_test_max)
yhat_train = model_fit.predict(x_train_min, x_train_max)

# # intersection between train index and train predictions (due to missing values in train index)
# if not isComplete(train):
#     train_index = list(set(yhat_train.index.values).intersection([timestamp.year for timestamp in train.index]))
#     yhat_train = yhat_train[train_index]

# score train, test and full datasets
test_scrs = score_predictions_fancy(test, yhat_test, model_name='arima'+'_'+'test'+'_'+key)
# score train, test and full datasets
train_scrs = score_predictions_fancy(train, yhat_train, model_name='arima'+'_'+'test'+'_'+key)

# %%
pd.concat([train_scrs, test_scrs], 1)
# Out:
#       arima_test_fda49275fbf5caf6-Others-temporary  \
# mae                                   5.976088e+00
# mse                                   1.581297e+02
# mape                                  7.617047e+15
# wape                                  3.763054e-01
# r2                                    6.327527e-01
#
#       arima_test_fda49275fbf5caf6-Others-temporary
# mae                                      14.856249
# mse                                     258.594850
# mape                                      0.203166
# wape                                      0.207780
# r2                                      -11.770116

# %% [markdown]
# ## SARIMAX example

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from random import random

# %%
# contrived train and test datasets
train1 = full_tt_series[full_keys[1]]['train']
test1 = full_tt_series[full_keys[1]]['test']
# train and test prediction intervals
x_train_min, x_train_max, x_test_min, x_test_max = train_test_min_max(train1, test1)

# fit model
model = SARIMAX(train, exog=train1, order=(1, 1, 1), seasonal_order=(0, 0, 0, 0))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict(test1.index.min(), test1.index.max(), exog=test1)
score_predictions_fancy(test, yhat)
# Out:
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# mae       9.361297
# mse     107.675520
# mape      0.127492
# wape      0.130927
# r2       -4.317310
# Name: , dtype: float64

# %%
yhat, test
# Out:
# (42    62.115492
#  43    62.161914
#  dtype: float64,
#  42    67.0
#  43    76.0
#  Name: area, dtype: float64)

# %% [markdown]
# ## VAR example

# %%
# X_train = X[:'2015']
# X_test = X['2016':]
X_train = X[:42]
X_test = X[42:]
x_test = X_test.values.reshape(-1)

# %%
from statsmodels.tsa.vector_ar.var_model import VAR
from random import random
# contrived dataset with dependency

# fit model
model = VAR(X_train)
model_fit = model.fit()
# make prediction
yhat = model_fit.forecast(model_fit.y, steps=2)
yhat = yhat.reshape(-1)
# Out:
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %%
score_predictions_fancy(x_test, yhat)
# Out:
# mae     1.293528e+13
# mse     1.031415e+27
# mape    5.444631e+27
# wape    2.674009e+10
# r2     -4.821817e+20
# Name: , dtype: float64

# %%
pd.DataFrame([x_test, yhat], columns=X_test.columns.tolist()*2, index=X_test.index)
# Out:
#     0307883b5d063703-Others-permanent  0307883b5d063703-Others-temporary  \
# 42                       6.700000e+01                       1.400000e+01
# 43                       4.055675e+11                       1.171640e+12
#
#     03e477d4ede00e89-Others-permanent  03e477d4ede00e89-Others-temporary  \
# 42                       4.350000e+02                       2.000000e+00
# 43                       3.012465e+13                       9.530837e+13
#
#     051e9cc7d7636816-Others-permanent  051e9cc7d7636816-Others-temporary  \
# 42                       1.300000e+01                           24.00000
# 43                       2.253153e+11                           30.05519
#
#     062ce4c17e84291e-Others-permanent  062ce4c17e84291e-Others-temporary  \
# 42                       1.200000e+01                            0.00000
# 43                       2.027838e+11                           -0.42416
#
#     074590cfc1c41ebf-Others-permanent  074590cfc1c41ebf-Others-temporary  \
# 42                       3.617000e+03                       1.530000e+02
# 43                       4.508559e+13                       1.622270e+12
#
#     07bba1a59af78f2d-Others-permanent  07bba1a59af78f2d-Others-temporary  \
# 42                       7.970000e+02                       0.000000e+00
# 43                       1.209943e+13                       1.820548e+13
#
#     07ce2e79e19977e9-Others-permanent  07ce2e79e19977e9-Others-temporary  \
# 42                            7.00000                          12.000000
# 43                            1.57659                           5.568787
#
#     07ed828db19fe8ca-Others-permanent  07ed828db19fe8ca-Others-temporary  \
# 42                       9.000000e+01                       0.000000e+00
# 43                       7.457936e+12                       2.365811e+13
#
#     09791645137aa877-Others-permanent  09791645137aa877-Others-temporary  \
# 42                       5.000000e+01                       0.000000e+00
# 43                       1.036450e+13                       1.802522e+11
#
#     0dcbfaab30eb40c1-Others-permanent  0dcbfaab30eb40c1-Others-temporary  \
# 42                       1.450000e+02                       1.350000e+02
# 43                       1.086020e+13                       1.176146e+14
#
#     0ea136556d12fc16-Others-permanent  0ea136556d12fc16-Others-temporary  \
# 42                       1.610000e+03                       2.010000e+02
# 43                       4.587419e+13                       2.816441e+12
#
#     1096f26c5a236d0b-Others-permanent  1096f26c5a236d0b-Others-temporary  \
# 42                         550.000000                          25.000000
# 43                         593.133343                           2.791014
#
#     10973d6049af898b-Others-permanent  10973d6049af898b-Others-temporary  \
# 42                         169.000000                         105.000000
# 43                         428.828549                         167.284786
#
#     114487007645c940-Others-permanent  114487007645c940-Others-temporary  \
# 42                       1.600000e+02                       2.000000e+01
# 43                       1.825054e+12                       1.802522e+12
#
#     11645a57d3a1d507-Others-permanent  11645a57d3a1d507-Others-temporary  \
# 42                       1.370000e+03                       2.000000e+02
# 43                       2.388342e+13                       8.449323e+12
#
#     11b6622567f98f3b-Others-permanent  11b6622567f98f3b-Others-temporary  \
# 42                       4.950000e+02                       0.000000e+00
# 43                       1.101792e+13                       1.126576e+13
#
#     13804a196311e1ba-Others-permanent  13804a196311e1ba-Others-temporary  \
# 42                       3.780000e+02                       8.700000e+01
# 43                       1.412727e+13                       9.463242e+11
#
#     164c8953d3af2bbe-Others-permanent  164c8953d3af2bbe-Others-temporary  \
# 42                           130.0000                            0.00000
# 43                           204.7426                           -3.55031
#
#     18e37d24ff8517ef-Others-permanent  18e37d24ff8517ef-Others-temporary  \
# 42                          53.000000                         200.000000
# 43                          81.183346                          94.839074
#
#     18fb5197aa553b9c-Others-permanent  18fb5197aa553b9c-Others-temporary  \
# 42                       2.920000e+02                       9.000000e+01
# 43                       6.759459e+12                       7.886035e+11
#
#     1bd7145ed1da044a-Others-permanent  1bd7145ed1da044a-Others-temporary  \
# 42                       3.380000e+02                       3.370000e+02
# 43                       8.703930e+13                       3.828107e+13
#
#     1d8a692643f9a15a-Others-permanent  1d8a692643f9a15a-Others-temporary  \
# 42                       5.840000e+02                          10.000000
# 43                       1.354145e+13                          13.549799
#
#     20589298110cd872-Others-permanent  20589298110cd872-Others-temporary  \
# 42                         258.000000                         210.000000
# 43                         311.431172                         248.288751
#
#     205ccde9be499e17-Others-permanent  205ccde9be499e17-Others-temporary  \
# 42                       2.375000e+03                          50.000000
# 43                       4.905114e+13                          52.455372
#
#     20e241460ce4140d-Others-permanent  20e241460ce4140d-Others-temporary  \
# 42                       2.000000e+01                       4.000000e+02
# 43                       7.052369e+12                       5.677945e+12
#
#     2631530645ac2ec8-Others-permanent  2631530645ac2ec8-Others-temporary  \
# 42                       5.350000e+02                       2.500000e+01
# 43                       3.744740e+13                       6.748193e+13
#
#     2a6b10e6e68be90e-Others-permanent  2a6b10e6e68be90e-Others-temporary  \
# 42                        1750.000000                         445.000000
# 43                        1978.026473                         402.215952
#
#     2ad055c7757d499d-Others-permanent  2ad055c7757d499d-Others-temporary  \
# 42                         945.000000                           0.000000
# 43                         687.497612                          31.690265
#
#     351174f21316c2f0-Others-permanent  351174f21316c2f0-Others-temporary  \
# 42                       8.700000e+01                       5.100000e+01
# 43                       4.956936e+11                       1.757459e+12
#
#     351bc0cbcce79ec9-Others-permanent  351bc0cbcce79ec9-Others-temporary  \
# 42                       8.170000e+02                       0.000000e+00
# 43                       6.196170e+12                       8.561981e+11
#
#     3a5d0e5eb1691b38-Others-permanent  3a5d0e5eb1691b38-Others-temporary  \
# 42                       8.600000e+01                       9.300000e+01
# 43                       5.182252e+12                       3.379729e+12
#
#     3a8618990d23351f-Others-permanent  3a8618990d23351f-Others-temporary  \
# 42                       2.250000e+02                       1.000000e+00
# 43                       1.937711e+12                       4.055675e+12
#
#     3cf541a13002d37b-Others-permanent  3cf541a13002d37b-Others-temporary  \
# 42                         170.000000                           0.000000
# 43                         358.920266                          -9.879833
#
#     3fdbc27a4bed0deb-Others-permanent  3fdbc27a4bed0deb-Others-temporary  \
# 42                        6786.000000                           0.000000
# 43                        6060.794983                         -16.717807
#
#     40abcc3eff7bcf73-Others-permanent  40abcc3eff7bcf73-Others-temporary  \
# 42                          1530.0000                           30.00000
# 43                          2263.5848                           84.13719
#
#     41e0f8ccfe523e0d-Others-permanent  41e0f8ccfe523e0d-Others-temporary  \
# 42                       1.470000e+02                       1.340000e+02
# 43                       1.029691e+13                       5.182252e+12
#
#     437130e27b6165ec-Others-permanent  437130e27b6165ec-Others-temporary  \
# 42                       1.770000e+02                       1.200000e+01
# 43                       2.275684e+12                       3.605045e+11
#
#     44d800c11a5f3bfa-Others-permanent  44d800c11a5f3bfa-Others-temporary  \
# 42                       8.220000e+02                           0.000000
# 43                       5.001999e+12                           2.049934
#
#     47564ef7b8c69829-Others-permanent  47564ef7b8c69829-Others-temporary  \
# 42                         708.000000                           8.000000
# 43                         766.003962                          13.595737
#
#     480b0f80325080af-Others-permanent  480b0f80325080af-Others-temporary  \
# 42                          380.00000                         145.000000
# 43                          556.32146                         129.374263
#
#     4b530007d167bd54-Others-permanent  4b530007d167bd54-Others-temporary  \
# 42                         169.000000                         110.000000
# 43                         181.909792                          94.725025
#
#     4c4428f2e4550a5a-Others-permanent  4c4428f2e4550a5a-Others-temporary  \
# 42                       2.710000e+02                       5.800000e+01
# 43                       3.086819e+12                       1.428499e+13
#
#     4de42e351006a2ae-Others-permanent  4de42e351006a2ae-Others-temporary  \
# 42                       4.000000e+01                       0.000000e+00
# 43                       1.870117e+12                       1.532144e+12
#
#     505ceb6546aa8435-Others-permanent  505ceb6546aa8435-Others-temporary  \
# 42                       1.050000e+02                           0.000000
# 43                       1.962496e+13                          -0.220904
#
#     50a2afbdc678a65f-Others-permanent  50a2afbdc678a65f-Others-temporary  \
# 42                        1575.000000                          65.000000
# 43                        2408.725422                         121.764475
#
#     51db62cb09adc2e8-Others-permanent  51db62cb09adc2e8-Others-temporary  \
# 42                       7.000000e+01                          46.000000
# 43                       3.379729e+12                          91.101391
#
#     5214b514b5b440be-Others-permanent  5214b514b5b440be-Others-temporary  \
# 42                       1.074000e+03                       1.500000e+01
# 43                       1.149108e+13                       1.126576e+12
#
#     56aa50429893f5ca-Others-permanent  56aa50429893f5ca-Others-temporary  \
# 42                           60.00000                          25.000000
# 43                           15.67243                          10.056402
#
#     588162e9cdf5d66d-Others-permanent  588162e9cdf5d66d-Others-temporary  \
# 42                         523.000000                          25.000000
# 43                         783.924822                          45.636517
#
#     5b3728d86ce29fd2-Others-permanent  5b3728d86ce29fd2-Others-temporary  \
# 42                       1.300000e+01                          10.000000
# 43                       6.083513e+11                           1.835652
#
#     5b6072f8f6d37acc-Others-permanent  5b6072f8f6d37acc-Others-temporary  \
# 42                          80.000000                            20.0000
# 43                         121.348722                            16.3986
#
#     5e1e131ec84f4c87-Others-permanent  5e1e131ec84f4c87-Others-temporary  \
# 42                       2.270000e+02                       2.200000e+01
# 43                       1.331613e+13                       1.126576e+13
#
#     5e7093a1cd2a8779-Others-permanent  5e7093a1cd2a8779-Others-temporary  \
# 42                        1225.000000                           5.000000
# 43                        1663.866694                         325.961308
#
#     60982e0f7928740a-Others-permanent  60982e0f7928740a-Others-temporary  \
# 42                          94.000000                          38.000000
# 43                         118.873488                         115.076919
#
#     617532f74ef8ed73-Others-permanent  617532f74ef8ed73-Others-temporary  \
# 42                       2.200000e+02                       2.000000e+01
# 43                       8.764765e+12                       2.703783e+12
#
#     6471ede39ca61b39-Others-permanent  6471ede39ca61b39-Others-temporary  \
# 42                       5.120000e+02                       6.800000e+01
# 43                       2.078083e+14                       4.848785e+13
#
#     64a227aa24370b17-Others-permanent  64a227aa24370b17-Others-temporary  \
# 42                       2.640000e+02                       5.000000e+00
# 43                       4.956936e+13                       2.253153e+11
#
#     66fdcb391ed58d3d-Others-permanent  66fdcb391ed58d3d-Others-temporary  \
# 42                         190.000000                           30.00000
# 43                         250.224641                           33.55555
#
#     68f01d67ad163f32-Others-permanent  68f01d67ad163f32-Others-temporary  \
# 42                       1.460000e+03                       0.000000e+00
# 43                       7.502999e+12                       7.886035e+11
#
#     6a7b8c3ab2bc6c38-Others-permanent  6a7b8c3ab2bc6c38-Others-temporary  \
# 42                       3.620000e+02                       1.600000e+01
# 43                       4.033144e+12                       8.787296e+12
#
#     6cce2bf873870afc-Others-permanent  6cce2bf873870afc-Others-temporary  \
# 42                       3.152000e+03                       0.000000e+00
# 43                       4.139042e+13                       2.027838e+13
#
#     6f911ef231b0efa7-Others-permanent  6f911ef231b0efa7-Others-temporary  \
# 42                       8.410000e+02                       8.500000e+01
# 43                       2.027838e+12                       3.605045e+12
#
#     70a4c62beba3c168-Others-permanent  70a4c62beba3c168-Others-temporary  \
# 42                       9.020000e+03                       1.300000e+02
# 43                       5.826653e+13                       1.802522e+12
#
#     71975b563db10671-Others-permanent  71975b563db10671-Others-temporary  \
# 42                           8.000000                            0.00000
# 43                          82.354788                            2.36601
#
#     72b65b337fc5302a-Others-permanent  72b65b337fc5302a-Others-temporary  \
# 42                       2.420000e+02                       8.000000e+01
# 43                       9.328053e+12                       4.483774e+12
#
#     746cc42bfb8f6b62-Others-permanent  746cc42bfb8f6b62-Others-temporary  \
# 42                          14.000000                           0.000000
# 43                        -281.901894                           5.258399
#
#     74d75dde6dc4a5ec-Others-permanent  74d75dde6dc4a5ec-Others-temporary  \
# 42                       1.430000e+02                       1.800000e+02
# 43                       6.894648e+12                       2.665480e+13
#
#     764cd56389d50070-Others-permanent  764cd56389d50070-Others-temporary  \
# 42                       1.260000e+02                       5.000000e+00
# 43                       4.799216e+12                       4.506306e+11
#
#     773cbe24d8fc9fea-Others-permanent  773cbe24d8fc9fea-Others-temporary  \
# 42                           0.000000                                0.0
# 43                          82.015204                                0.0
#
#     77c880feff17c521-Others-permanent  77c880feff17c521-Others-temporary  \
# 42                         169.000000                         117.000000
# 43                         362.510521                         109.999899
#
#     782568ced6ad8838-Others-permanent  782568ced6ad8838-Others-temporary  \
# 42                       3.500000e+01                         400.000000
# 43                       6.196170e+12                         321.825063
#
#     783dbed4df67af9f-Others-permanent  783dbed4df67af9f-Others-temporary  \
# 42                        2516.000000                          64.000000
# 43                        2595.121244                         135.701842
#
#     7926ffd2861f8dbc-Others-permanent  7926ffd2861f8dbc-Others-temporary  \
# 42                          40.000000                          45.000000
# 43                         156.262121                          49.414674
#
#     7b95e27ce402e6e5-Others-permanent  7b95e27ce402e6e5-Others-temporary  \
# 42                         145.000000                          10.000000
# 43                         135.917503                          10.690954
#
#     7e56bd83460aabc7-Others-permanent  7e56bd83460aabc7-Others-temporary  \
# 42                       1.933000e+03                       1.820000e+02
# 43                       2.280191e+13                       2.478468e+12
#
#     7f076b180f941ec8-Others-permanent  7f076b180f941ec8-Others-temporary  \
# 42                       5.500000e+01                       2.110000e+03
# 43                       1.396955e+12                       5.069594e+13
#
#     807c5037e6993f2c-Others-permanent  807c5037e6993f2c-Others-temporary  \
# 42                       2.000000e+02                       1.200000e+02
# 43                       2.253153e+11                       2.253153e+11
#
#     80e8ffb027590a74-Others-permanent  80e8ffb027590a74-Others-temporary  \
# 42                        1650.000000                         217.000000
# 43                        1241.582574                         238.185664
#
#     841ef18dcb3dbc3e-Others-permanent  841ef18dcb3dbc3e-Others-temporary  \
# 42                       1.890000e+03                         110.000000
# 43                       4.393648e+12                          52.476007
#
#     855f882ce507aba5-Others-permanent  855f882ce507aba5-Others-temporary  \
# 42                         123.000000                          64.000000
# 43                         247.839383                          64.018158
#
#     857b720c7c979ae1-Others-permanent  857b720c7c979ae1-Others-temporary  \
# 42                           0.000000                                0.0
# 43                          39.200959                                0.0
#
#     85adcb13676b6172-Others-permanent  85adcb13676b6172-Others-temporary  \
# 42                       0.000000e+00                       0.000000e+00
# 43                       2.658720e+12                       1.734928e+12
#
#     86d92d4b0a058014-Others-permanent  86d92d4b0a058014-Others-temporary  \
# 42                         675.000000                           0.000000
# 43                        1746.207344                          16.151419
#
#     878bd5338ba55697-Others-permanent  878bd5338ba55697-Others-temporary  \
# 42                        2985.000000                          43.000000
# 43                        7825.829339                         285.814165
#
#     8910840651ee3971-Others-permanent  8910840651ee3971-Others-temporary  \
# 42                         882.000000                          35.000000
# 43                        1223.035961                          42.548975
#
#     8a4ab531676691da-Others-permanent  8a4ab531676691da-Others-temporary  \
# 42                         320.000000                       12500.000000
# 43                         368.843859                       13025.369793
#
#     8ca7766621b0ffe9-Others-permanent  8ca7766621b0ffe9-Others-temporary  \
# 42                           80.00000                        9400.000000
# 43                          153.43331                        8102.277807
#
#     8e0eb10270d768f8-Others-permanent  8e0eb10270d768f8-Others-temporary  \
# 42                       1.090000e+03                       0.000000e+00
# 43                       2.106698e+13                       4.517572e+13
#
#     8ef25b4985bc557a-Others-permanent  8ef25b4985bc557a-Others-temporary  \
# 42                        1512.000000                         150.000000
# 43                        1477.988471                         160.943344
#
#     902f3a9003f7e637-Others-permanent  902f3a9003f7e637-Others-temporary  \
# 42                       4.300000e+02                       1.050000e+02
# 43                       2.169786e+13                       6.748193e+13
#
#     93656feaf53efbef-Others-permanent  93656feaf53efbef-Others-temporary  \
# 42                       6.010000e+02                       1.000000e+02
# 43                       5.234074e+13                       3.402261e+12
#
#     960b4f2c94a2fb2c-Others-permanent  960b4f2c94a2fb2c-Others-temporary  \
# 42                       5.400000e+02                       1.200000e+02
# 43                       2.784897e+13                       1.306829e+13
#
#     9bc907eeb9e3fc52-Others-permanent  9bc907eeb9e3fc52-Others-temporary  \
# 42                          20.000000                           0.000000
# 43                         -20.236147                          -0.165711
#
#     9bd4f108a319de42-Others-permanent  9bd4f108a319de42-Others-temporary  \
# 42                       1.000000e+01                       1.500000e+02
# 43                       7.660720e+11                       1.915180e+12
#
#     9ce50fa197613de1-Others-permanent  9ce50fa197613de1-Others-temporary  \
# 42                          48.000000                          76.000000
# 43                           6.174808                           8.949344
#
#     9d8776ac0a78d908-Others-permanent  9d8776ac0a78d908-Others-temporary  \
# 42                       6.700000e+01                       0.000000e+00
# 43                       5.858198e+11                       2.253153e+11
#
#     a18af8fbae254d86-Others-permanent  a18af8fbae254d86-Others-temporary  \
# 42                       2.300000e+01                       2.400000e+01
# 43                       1.689865e+12                       1.171640e+12
#
#     a1b03f0e4d79b4fe-Others-permanent  a1b03f0e4d79b4fe-Others-temporary  \
# 42                       1.740000e+02                       6.000000e+01
# 43                       4.461243e+12                       1.802522e+12
#
#     a245de687a867003-Others-permanent  a245de687a867003-Others-temporary  \
# 42                       0.000000e+00                       0.000000e+00
# 43                       6.308828e+11                       2.027838e+11
#
#     a454a6655aaaaaed-Others-permanent  a454a6655aaaaaed-Others-temporary  \
# 42                       2.450000e+02                       6.200000e+01
# 43                       4.190864e+12                       4.161573e+13
#
#     a4d1e1ff1bc3b830-Others-permanent  a4d1e1ff1bc3b830-Others-temporary  \
# 42                       1.600000e+02                       5.000000e+00
# 43                       9.530837e+12                       2.298216e+13
#
#     a51be58f39d1d625-Others-permanent  a51be58f39d1d625-Others-temporary  \
# 42                       2.400000e+01                       2.380000e+02
# 43                       3.559982e+12                       4.093979e+13
#
#     a7187a1b5b870cf4-Others-permanent  a7187a1b5b870cf4-Others-temporary  \
# 42                            0.00000                           0.000000
# 43                          129.98177                           1.852851
#
#     ab984377b2dc0284-Others-permanent  ab984377b2dc0284-Others-temporary  \
# 42                       1.520000e+02                       2.700000e+01
# 43                       1.126576e+12                       1.196424e+13
#
#     abcadd700f8948e3-Others-permanent  abcadd700f8948e3-Others-temporary  \
# 42                         391.000000                          60.000000
# 43                         638.286339                         142.726161
#
#     ad622472210b0b57-Others-permanent  ad622472210b0b57-Others-temporary  \
# 42                       7.350000e+02                       2.400000e+02
# 43                       1.297816e+13                       1.399659e+14
#
#     ae345f007f327b22-Others-permanent  ae345f007f327b22-Others-temporary  \
# 42                        1117.000000                          43.000000
# 43                        1741.868088                         110.322179
#
#     b0e4b4b27117562a-Others-permanent  b0e4b4b27117562a-Others-temporary  \
# 42                         371.000000                          40.000000
# 43                         873.817714                          25.971699
#
#     b4829f1e221d9778-Others-permanent  b4829f1e221d9778-Others-temporary  \
# 42                           5.000000                           88.00000
# 43                          48.735261                            4.74494
#
#     b4bb04d2a6472ea0-Others-permanent  b4bb04d2a6472ea0-Others-temporary  \
# 42                       3.500000e+01                       6.000000e+00
# 43                       1.306829e+12                       3.379729e+11
#
#     b73e63cd3a2904c9-Others-permanent  b73e63cd3a2904c9-Others-temporary  \
# 42                       9.300000e+01                       1.770000e+02
# 43                       1.171640e+13                       6.759459e+12
#
#     ba23b66825fc1c91-Others-permanent  ba23b66825fc1c91-Others-temporary  \
# 42                         248.000000                         150.000000
# 43                         939.790214                         112.292468
#
#     ba4547c678a9a2e6-Others-permanent  ba4547c678a9a2e6-Others-temporary  \
# 42                       5.920000e+02                       6.000000e+01
# 43                       3.949777e+13                       5.632882e+12
#
#     bce36d2f8aa39d8b-Others-permanent  bce36d2f8aa39d8b-Others-temporary  \
# 42                         2309.00000                         365.000000
# 43                         2493.29042                         283.993336
#
#     be4424aa54f8d2ae-Others-permanent  be4424aa54f8d2ae-Others-temporary  \
# 42                           838.0000                          10.000000
# 43                           843.8988                          10.846074
#
#     be8a37473dc63db0-Others-permanent  be8a37473dc63db0-Others-temporary  \
# 42                        1630.000000                          136.00000
# 43                        2554.747567                          122.72947
#
#     c0019c9a4b4819f2-Others-permanent  c0019c9a4b4819f2-Others-temporary  \
# 42                       9.000000e+01                       0.000000e+00
# 43                       1.937711e+12                       5.632882e+11
#
#     c118b149223ba711-Others-permanent  c118b149223ba711-Others-temporary  \
# 42                       2.000000e+01                           5.000000
# 43                       4.956936e+11                          -0.138783
#
#     c129d0cd5f1afd51-Others-permanent  c129d0cd5f1afd51-Others-temporary  \
# 42                       9.670000e+02                           0.000000
# 43                       6.682851e+13                          -3.403296
#
#     c45d8ddba643c0d7-Others-permanent  c45d8ddba643c0d7-Others-temporary  \
# 42                       3.440000e+02                       1.500000e+01
# 43                       3.176946e+12                       5.632882e+11
#
#     cb23149538de1c42-Others-permanent  cb23149538de1c42-Others-temporary  \
# 42                         686.000000                          58.000000
# 43                         810.187922                          43.479029
#
#     cdc89121a4b9478b-Others-permanent  cdc89121a4b9478b-Others-temporary  \
# 42                         122.000000                         334.000000
# 43                          87.453989                         380.448731
#
#     cead2cbd1f8f0b86-Others-permanent  cead2cbd1f8f0b86-Others-temporary  \
# 42                         687.000000                          59.000000
# 43                         365.308555                          61.509275
#
#     cf96db4cc35ea025-Others-permanent  cf96db4cc35ea025-Others-temporary  \
# 42                       0.000000e+00                           0.000000
# 43                       2.365811e+13                          -9.411884
#
#     d0f5f5b9fcecb0d8-Others-permanent  d0f5f5b9fcecb0d8-Others-temporary  \
# 42                          69.000000                          50.000000
# 43                          54.965191                          36.111198
#
#     d42d0e216f57b2ae-Others-permanent  d42d0e216f57b2ae-Others-temporary  \
# 42                       5.000000e+00                       0.000000e+00
# 43                       3.469855e+13                       4.055675e+12
#
#     d6f1f98b1745e004-Others-permanent  d6f1f98b1745e004-Others-temporary  \
# 42                       2.069000e+03                       4.400000e+02
# 43                       4.986227e+13                       2.748847e+12
#
#     d6ffd6d7dfe22d57-Others-permanent  d6ffd6d7dfe22d57-Others-temporary  \
# 42                         570.000000                          30.000000
# 43                        1008.255004                         404.524306
#
#     de1994d393ef525a-Others-permanent  de1994d393ef525a-Others-temporary  \
# 42                         513.000000                           0.000000
# 43                         167.057227                           2.439216
#
#     df19203419d2ea64-Others-permanent  df19203419d2ea64-Others-temporary  \
# 42                       5.500000e+02                       3.000000e+01
# 43                       4.528837e+12                       1.126576e+12
#
#     df2cd1cbe849ebd0-Others-permanent  df2cd1cbe849ebd0-Others-temporary  \
# 42                       1.641000e+03                       8.000000e+01
# 43                       4.564888e+13                       4.420686e+13
#
#     e635f6b0f8a98808-Others-permanent  e635f6b0f8a98808-Others-temporary  \
# 42                            232.000                          74.000000
# 43                            308.994                         134.277873
#
#     eac302b92f87d9ca-Others-permanent  eac302b92f87d9ca-Others-temporary  \
# 42                       1.083000e+03                       1.100000e+02
# 43                       2.273431e+13                       5.876223e+13
#
#     ec84c1e86735dc9b-Others-permanent  ec84c1e86735dc9b-Others-temporary  \
# 42                       1.220500e+04                       1.500000e+01
# 43                       7.210089e+13                       1.379831e+14
#
#     f1fd357c5adaa8dc-Others-permanent  f1fd357c5adaa8dc-Others-temporary  \
# 42                       2.260000e+03                           0.000000
# 43                       9.305521e+12                           0.807585
#
#     f39d21744916469c-Others-permanent  f39d21744916469c-Others-temporary  \
# 42                         240.000000                           0.000000
# 43                         367.505661                           5.302426
#
#     f3c2cc112eb0e6fe-Others-permanent  f3c2cc112eb0e6fe-Others-temporary  \
# 42                       9.300000e+01                       0.000000e+00
# 43                       6.308828e+12                       9.575900e+12
#
#     f4612b8b5a8223b5-Others-permanent  f4612b8b5a8223b5-Others-temporary  \
# 42                         300.000000                           0.000000
# 43                         217.486813                           2.408633
#
#     f67358b81451a8d1-Others-permanent  f67358b81451a8d1-Others-temporary  \
# 42                       5.000000e+00                            4.00000
# 43                       1.329360e+12                            5.58327
#
#     f8e70145d73bd728-Others-permanent  f8e70145d73bd728-Others-temporary  \
# 42                       5.020000e+02                       2.900000e+01
# 43                       8.426792e+12                       5.632882e+11
#
#     fa005e1ffef6032a-Others-permanent  fa005e1ffef6032a-Others-temporary  \
# 42                       3.900000e+02                          10.000000
# 43                       1.351892e+12                          15.091648
#
#     fae378a53734da72-Others-permanent  fae378a53734da72-Others-temporary  \
# 42                       5.950000e+02                       2.900000e+01
# 43                       8.336666e+12                       7.660720e+11
#
#     fda49275fbf5caf6-Others-permanent  fda49275fbf5caf6-Others-temporary  \
# 42                         350.000000                           5.000000
# 43                         343.277353                           4.147281
#
#     0307883b5d063703-Others-permanent  0307883b5d063703-Others-temporary  \
# 42                       7.600000e+01                       1.400000e+01
# 43                       2.313134e+11                       1.569065e+12
#
#     03e477d4ede00e89-Others-permanent  03e477d4ede00e89-Others-temporary  \
# 42                       7.300000e+02                       0.000000e+00
# 43                       3.105970e+13                       9.953068e+13
#
#     051e9cc7d7636816-Others-permanent  051e9cc7d7636816-Others-temporary  \
# 42                       1.200000e+01                          24.000000
# 43                       3.540535e+11                          30.236091
#
#     062ce4c17e84291e-Others-permanent  062ce4c17e84291e-Others-temporary  \
# 42                       1.100000e+01                           0.000000
# 43                       6.114381e+11                           0.620909
#
#     074590cfc1c41ebf-Others-permanent  074590cfc1c41ebf-Others-temporary  \
# 42                       3.282000e+03                       1.530000e+02
# 43                       7.305129e+13                       2.817531e+12
#
#     07bba1a59af78f2d-Others-permanent  07bba1a59af78f2d-Others-temporary  \
# 42                       7.870000e+02                       0.000000e+00
# 43                       1.468880e+13                       1.608268e+13
#
#     07ce2e79e19977e9-Others-permanent  07ce2e79e19977e9-Others-temporary  \
# 42                          10.000000                           8.000000
# 43                         -12.932932                           4.911359
#
#     07ed828db19fe8ca-Others-permanent  07ed828db19fe8ca-Others-temporary  \
# 42                       8.300000e+01                       0.000000e+00
# 43                       1.238942e+13                       3.264576e+13
#
#     09791645137aa877-Others-permanent  09791645137aa877-Others-temporary  \
# 42                       1.250000e+02                       0.000000e+00
# 43                       1.627104e+13                       1.028422e+11
#
#     0dcbfaab30eb40c1-Others-permanent  0dcbfaab30eb40c1-Others-temporary  \
# 42                       2.330000e+02                       1.350000e+02
# 43                       1.973310e+13                       1.500492e+14
#
#     0ea136556d12fc16-Others-permanent  0ea136556d12fc16-Others-temporary  \
# 42                       1.610000e+03                       1.140000e+02
# 43                       4.894126e+13                       2.956575e+12
#
#     1096f26c5a236d0b-Others-permanent  1096f26c5a236d0b-Others-temporary  \
# 42                       5.700000e+02                       1.500000e+01
# 43                       1.915180e+12                       3.605045e+11
#
#     10973d6049af898b-Others-permanent  10973d6049af898b-Others-temporary  \
# 42                         183.000000                         105.000000
# 43                         724.702329                         160.133205
#
#     114487007645c940-Others-permanent  114487007645c940-Others-temporary  \
# 42                       6.500000e+01                       0.000000e+00
# 43                       3.540177e+12                       2.963575e+12
#
#     11645a57d3a1d507-Others-permanent  11645a57d3a1d507-Others-temporary  \
# 42                       8.020000e+02                       3.000000e+01
# 43                       4.187667e+13                       1.732066e+13
#
#     11b6622567f98f3b-Others-permanent  11b6622567f98f3b-Others-temporary  \
# 42                       4.550000e+02                       0.000000e+00
# 43                       1.775706e+13                       1.430832e+13
#
#     13804a196311e1ba-Others-permanent  13804a196311e1ba-Others-temporary  \
# 42                       5.490000e+02                       1.100000e+02
# 43                       1.172304e+13                       6.294545e+11
#
#     164c8953d3af2bbe-Others-permanent  164c8953d3af2bbe-Others-temporary  \
# 42                       2.300000e+02                       0.000000e+00
# 43                       1.734928e+13                       4.506306e+11
#
#     18e37d24ff8517ef-Others-permanent  18e37d24ff8517ef-Others-temporary  \
# 42                           48.00000                          50.000000
# 43                           77.29879                          98.679084
#
#     18fb5197aa553b9c-Others-permanent  18fb5197aa553b9c-Others-temporary  \
# 42                       3.220000e+02                       5.000000e+01
# 43                       7.908261e+12                       1.036020e+12
#
#     1bd7145ed1da044a-Others-permanent  1bd7145ed1da044a-Others-temporary  \
# 42                       3.480000e+02                       3.370000e+02
# 43                       1.569702e+14                       3.423607e+13
#
#     1d8a692643f9a15a-Others-permanent  1d8a692643f9a15a-Others-temporary  \
# 42                       6.900000e+02                          10.000000
# 43                       2.803487e+13                          10.743997
#
#     20589298110cd872-Others-permanent  20589298110cd872-Others-temporary  \
# 42                         361.000000                         270.000000
# 43                         378.856584                         265.752364
#
#     205ccde9be499e17-Others-permanent  205ccde9be499e17-Others-temporary  \
# 42                       2.285000e+03                          40.000000
# 43                       8.362155e+13                          77.352753
#
#     20e241460ce4140d-Others-permanent  20e241460ce4140d-Others-temporary  \
# 42                       2.000000e+01                       5.500000e+02
# 43                       1.107589e+13                       9.592063e+12
#
#     2631530645ac2ec8-Others-permanent  2631530645ac2ec8-Others-temporary  \
# 42                       4.450000e+02                       0.000000e+00
# 43                       5.709646e+13                       1.064537e+14
#
#     2a6b10e6e68be90e-Others-permanent  2a6b10e6e68be90e-Others-temporary  \
# 42                       1.760000e+03                       4.500000e+02
# 43                       1.153614e+13                       4.055675e+11
#
#     2ad055c7757d499d-Others-permanent  2ad055c7757d499d-Others-temporary  \
# 42                       1.147000e+03                       0.000000e+00
# 43                       7.908567e+12                       6.759459e+12
#
#     351174f21316c2f0-Others-permanent  351174f21316c2f0-Others-temporary  \
# 42                       6.100000e+01                       4.700000e+01
# 43                       7.779125e+11                       2.602132e+12
#
#     351bc0cbcce79ec9-Others-permanent  351bc0cbcce79ec9-Others-temporary  \
# 42                       8.170000e+02                       0.000000e+00
# 43                       1.333417e+13                       1.299218e+12
#
#     3a5d0e5eb1691b38-Others-permanent  3a5d0e5eb1691b38-Others-temporary  \
# 42                       7.200000e+01                       3.000000e+00
# 43                       6.785090e+12                       4.181680e+12
#
#     3a8618990d23351f-Others-permanent  3a8618990d23351f-Others-temporary  \
# 42                       5.000000e+01                       0.000000e+00
# 43                       1.991847e+13                       5.693232e+12
#
#     3cf541a13002d37b-Others-permanent  3cf541a13002d37b-Others-temporary  \
# 42                          90.000000                          20.000000
# 43                         550.498445                          72.798694
#
#     3fdbc27a4bed0deb-Others-permanent  3fdbc27a4bed0deb-Others-temporary  \
# 42                        6786.000000                           0.000000
# 43                        5819.665131                         -10.715561
#
#     40abcc3eff7bcf73-Others-permanent  40abcc3eff7bcf73-Others-temporary  \
# 42                        1660.000000                          25.000000
# 43                        2262.346042                          79.079825
#
#     41e0f8ccfe523e0d-Others-permanent  41e0f8ccfe523e0d-Others-temporary  \
# 42                       8.900000e+01                       3.000000e+00
# 43                       1.668923e+13                       9.263354e+12
#
#     437130e27b6165ec-Others-permanent  437130e27b6165ec-Others-temporary  \
# 42                       1.010000e+02                       2.000000e+00
# 43                       4.702105e+12                       5.211485e+11
#
#     44d800c11a5f3bfa-Others-permanent  44d800c11a5f3bfa-Others-temporary  \
# 42                       5.670000e+02                           0.000000
# 43                       1.258560e+13                           6.150551
#
#     47564ef7b8c69829-Others-permanent  47564ef7b8c69829-Others-temporary  \
# 42                         708.000000                          11.000000
# 43                         829.808015                          12.983311
#
#     480b0f80325080af-Others-permanent  480b0f80325080af-Others-temporary  \
# 42                         262.000000                          25.000000
# 43                         567.827006                         121.760641
#
#     4b530007d167bd54-Others-permanent  4b530007d167bd54-Others-temporary  \
# 42                       1.690000e+02                         110.000000
# 43                       6.759459e+11                         107.103388
#
#     4c4428f2e4550a5a-Others-permanent  4c4428f2e4550a5a-Others-temporary  \
# 42                       2.720000e+02                       9.100000e+01
# 43                       5.593373e+12                       1.456105e+13
#
#     4de42e351006a2ae-Others-permanent  4de42e351006a2ae-Others-temporary  \
# 42                       4.000000e+01                       0.000000e+00
# 43                       1.179551e+12                       2.001530e+12
#
#     505ceb6546aa8435-Others-permanent  505ceb6546aa8435-Others-temporary  \
# 42                       1.150000e+02                           0.000000
# 43                       3.274013e+13                           5.948746
#
#     50a2afbdc678a65f-Others-permanent  50a2afbdc678a65f-Others-temporary  \
# 42                       1.975000e+03                          65.000000
# 43                       3.830360e+13                         122.181182
#
#     51db62cb09adc2e8-Others-permanent  51db62cb09adc2e8-Others-temporary  \
# 42                       7.000000e+01                          46.000000
# 43                       9.271854e+12                         110.225117
#
#     5214b514b5b440be-Others-permanent  5214b514b5b440be-Others-temporary  \
# 42                       1.059000e+03                       1.500000e+01
# 43                       1.991697e+13                       1.318297e+12
#
#     56aa50429893f5ca-Others-permanent  56aa50429893f5ca-Others-temporary  \
# 42                       1.000000e+01                       0.000000e+00
# 43                       1.554675e+12                       2.253153e+12
#
#     588162e9cdf5d66d-Others-permanent  588162e9cdf5d66d-Others-temporary  \
# 42                       5.860000e+02                          25.000000
# 43                       5.407567e+12                          25.299898
#
#     5b3728d86ce29fd2-Others-permanent  5b3728d86ce29fd2-Others-temporary  \
# 42                       1.500000e+01                           0.000000
# 43                       1.361046e+12                           5.580722
#
#     5b6072f8f6d37acc-Others-permanent  5b6072f8f6d37acc-Others-temporary  \
# 42                          80.000000                          25.000000
# 43                          56.408011                          22.086342
#
#     5e1e131ec84f4c87-Others-permanent  5e1e131ec84f4c87-Others-temporary  \
# 42                       4.290000e+02                       0.000000e+00
# 43                       2.365291e+13                       1.499357e+13
#
#     5e7093a1cd2a8779-Others-permanent  5e7093a1cd2a8779-Others-temporary  \
# 42                       1.346000e+03                       2.000000e+01
# 43                       1.834066e+13                       4.506306e+13
#
#     60982e0f7928740a-Others-permanent  60982e0f7928740a-Others-temporary  \
# 42                          67.000000                           2.000000
# 43                         131.469707                           2.549213
#
#     617532f74ef8ed73-Others-permanent  617532f74ef8ed73-Others-temporary  \
# 42                       2.250000e+02                       2.000000e+01
# 43                       1.741531e+13                       4.246515e+12
#
#     6471ede39ca61b39-Others-permanent  6471ede39ca61b39-Others-temporary  \
# 42                       5.040000e+02                       1.030000e+02
# 43                       1.317419e+14                       2.820471e+13
#
#     64a227aa24370b17-Others-permanent  64a227aa24370b17-Others-temporary  \
# 42                       2.210000e+02                       5.000000e+00
# 43                       4.010106e+13                       1.931004e+12
#
#     66fdcb391ed58d3d-Others-permanent  66fdcb391ed58d3d-Others-temporary  \
# 42                       2.400000e+02                       3.000000e+01
# 43                       3.559982e+12                       1.126576e+13
#
#     68f01d67ad163f32-Others-permanent  68f01d67ad163f32-Others-temporary  \
# 42                       1.490000e+03                       0.000000e+00
# 43                       1.250062e+13                       6.750371e+11
#
#     6a7b8c3ab2bc6c38-Others-permanent  6a7b8c3ab2bc6c38-Others-temporary  \
# 42                       3.220000e+02                       0.000000e+00
# 43                       7.461683e+12                       1.109477e+13
#
#     6cce2bf873870afc-Others-permanent  6cce2bf873870afc-Others-temporary  \
# 42                       3.167000e+03                       0.000000e+00
# 43                       7.282749e+13                       2.574741e+13
#
#     6f911ef231b0efa7-Others-permanent  6f911ef231b0efa7-Others-temporary  \
# 42                       3.910000e+02                       8.500000e+01
# 43                       4.785500e+12                       1.129566e+13
#
#     70a4c62beba3c168-Others-permanent  70a4c62beba3c168-Others-temporary  \
# 42                       9.020000e+03                       1.300000e+02
# 43                       1.124533e+14                       2.829735e+12
#
#     71975b563db10671-Others-permanent  71975b563db10671-Others-temporary  \
# 42                          26.000000                           0.000000
# 43                         464.291527                          46.877986
#
#     72b65b337fc5302a-Others-permanent  72b65b337fc5302a-Others-temporary  \
# 42                       2.400000e+02                       8.000000e+00
# 43                       1.262271e+13                       9.630932e+12
#
#     746cc42bfb8f6b62-Others-permanent  746cc42bfb8f6b62-Others-temporary  \
# 42                          14.000000                           0.000000
# 43                        -151.599499                           9.443346
#
#     74d75dde6dc4a5ec-Others-permanent  74d75dde6dc4a5ec-Others-temporary  \
# ...
# 42                         135.000000                          10.000000
# 43                         152.470893                           9.448047
#
#     7e56bd83460aabc7-Others-permanent  7e56bd83460aabc7-Others-temporary  \
# 42                       2.083000e+03                       1.320000e+02
# 43                       1.445101e+14                       4.117907e+12
#
#     7f076b180f941ec8-Others-permanent  7f076b180f941ec8-Others-temporary  \
# 42                       7.000000e+01                       1.570000e+03
# 43                       2.284222e+12                       7.950728e+13
#
#     807c5037e6993f2c-Others-permanent  807c5037e6993f2c-Others-temporary  \
# 42                       2.050000e+02                       3.000000e+01
# 43                       5.790328e+11                       2.413400e+11
#
#     80e8ffb027590a74-Others-permanent  80e8ffb027590a74-Others-temporary  \
# 42                        1448.000000                         239.000000
# 43                        1770.980637                         238.666265
#
#     841ef18dcb3dbc3e-Others-permanent  841ef18dcb3dbc3e-Others-temporary  \
# 42                       9.900000e+02                          20.000000
# 43                       1.131318e+13                          50.728619
#
#     855f882ce507aba5-Others-permanent  855f882ce507aba5-Others-temporary  \
# 42                       1.430000e+02                       5.400000e+01
# 43                       6.106044e+13                       1.464549e+12
#
#     857b720c7c979ae1-Others-permanent  857b720c7c979ae1-Others-temporary  \
# 42                          40.000000                                0.0
# 43                          38.222432                                0.0
#
#     85adcb13676b6172-Others-permanent  85adcb13676b6172-Others-temporary  \
# 42                       0.000000e+00                       0.000000e+00
# 43                       1.875891e+12                       2.340262e+12
#
#     86d92d4b0a058014-Others-permanent  86d92d4b0a058014-Others-temporary  \
# 42                         780.000000                           0.000000
# 43                        2163.201198                         -11.671232
#
#     878bd5338ba55697-Others-permanent  878bd5338ba55697-Others-temporary  \
# 42                       2.985000e+03                       4.300000e+01
# 43                       2.352066e+14                       4.596432e+13
#
#     8910840651ee3971-Others-permanent  8910840651ee3971-Others-temporary  \
# 42                          882.00000                          35.000000
# 43                         1603.83665                          64.861774
#
#     8a4ab531676691da-Others-permanent  8a4ab531676691da-Others-temporary  \
# 42                         325.000000                       12000.000000
# 43                         392.286721                       13921.839325
#
#     8ca7766621b0ffe9-Others-permanent  8ca7766621b0ffe9-Others-temporary  \
# 42                          74.000000                        7670.000000
# 43                         204.657961                       10582.684057
#
#     8e0eb10270d768f8-Others-permanent  8e0eb10270d768f8-Others-temporary  \
# 42                       1.140000e+03                       0.000000e+00
# 43                       1.980522e+13                       7.082476e+13
#
#     8ef25b4985bc557a-Others-permanent  8ef25b4985bc557a-Others-temporary  \
# 42                        1482.000000                         150.000000
# 43                        1392.656015                         157.474338
#
#     902f3a9003f7e637-Others-permanent  902f3a9003f7e637-Others-temporary  \
# 42                       4.170000e+02                       8.000000e+01
# 43                       2.268452e+13                       8.430370e+13
#
#     93656feaf53efbef-Others-permanent  93656feaf53efbef-Others-temporary  \
# 42                       3.740000e+02                       2.500000e+01
# 43                       8.201961e+13                       5.724179e+12
#
#     960b4f2c94a2fb2c-Others-permanent  960b4f2c94a2fb2c-Others-temporary  \
# 42                       7.000000e+02                       2.800000e+02
# 43                       4.373606e+13                       1.230266e+13
#
#     9bc907eeb9e3fc52-Others-permanent  9bc907eeb9e3fc52-Others-temporary  \
# 42                          10.000000                            0.00000
# 43                          52.052961                            3.23785
#
#     9bd4f108a319de42-Others-permanent  9bd4f108a319de42-Others-temporary  \
# 42                       1.000000e+01                       1.500000e+02
# 43                       1.158311e+12                       2.827094e+12
#
#     9ce50fa197613de1-Others-permanent  9ce50fa197613de1-Others-temporary  \
# 42                           5.000000                           0.000000
# 43                          16.025159                          10.740702
#
#     9d8776ac0a78d908-Others-permanent  9d8776ac0a78d908-Others-temporary  \
# 42                       7.900000e+01                       0.000000e+00
# 43                       9.205602e+11                       1.281871e+11
#
#     a18af8fbae254d86-Others-permanent  a18af8fbae254d86-Others-temporary  \
# 42                       3.700000e+01                       2.400000e+01
# 43                       2.676080e+12                       1.930128e+12
#
#     a1b03f0e4d79b4fe-Others-permanent  a1b03f0e4d79b4fe-Others-temporary  \
# 42                       1.740000e+02                       6.000000e+01
# 43                       8.425470e+12                       2.673195e+12
#
#     a245de687a867003-Others-permanent  a245de687a867003-Others-temporary  \
# 42                       0.000000e+00                       0.000000e+00
# 43                       5.168268e+11                       1.155508e+11
#
#     a454a6655aaaaaed-Others-permanent  a454a6655aaaaaed-Others-temporary  \
# 42                       1.250000e+02                       1.000000e+01
# 43                       8.250511e+12                       4.716998e+13
#
#     a4d1e1ff1bc3b830-Others-permanent  a4d1e1ff1bc3b830-Others-temporary  \
# 42                       1.600000e+02                       0.000000e+00
# 43                       1.279869e+13                       3.136130e+13
#
#     a51be58f39d1d625-Others-permanent  a51be58f39d1d625-Others-temporary  \
# 42                       5.000000e+01                       3.070000e+02
# 43                       4.823659e+12                       2.966612e+13
#
#     a7187a1b5b870cf4-Others-permanent  a7187a1b5b870cf4-Others-temporary  \
# 42                           0.000000                           0.000000
# 43                         -66.090635                           0.989306
#
#     ab984377b2dc0284-Others-permanent  ab984377b2dc0284-Others-temporary  \
# 42                       1.730000e+02                       7.500000e+01
# 43                       1.791024e+12                       1.831958e+13
#
#     abcadd700f8948e3-Others-permanent  abcadd700f8948e3-Others-temporary  \
# 42                         480.000000                          20.000000
# 43                         663.622021                          82.142715
#
#     ad622472210b0b57-Others-permanent  ad622472210b0b57-Others-temporary  \
# 42                       5.850000e+02                       2.400000e+02
# 43                       2.119492e+13                       1.475960e+14
#
#     ae345f007f327b22-Others-permanent  ae345f007f327b22-Others-temporary  \
# 42                       1.117000e+03                       4.300000e+01
# 43                       2.176546e+13                       3.267072e+12
#
#     b0e4b4b27117562a-Others-permanent  b0e4b4b27117562a-Others-temporary  \
# 42                         471.000000                           43.00000
# 43                         789.166464                          102.99674
#
#     b4829f1e221d9778-Others-permanent  b4829f1e221d9778-Others-temporary  \
# 42                           5.000000                          90.000000
# 43                          69.196456                           6.097911
#
#     b4bb04d2a6472ea0-Others-permanent  b4bb04d2a6472ea0-Others-temporary  \
# 42                       3.500000e+01                       6.000000e+00
# 43                       2.277394e+12                       3.055908e+11
#
#     b73e63cd3a2904c9-Others-permanent  b73e63cd3a2904c9-Others-temporary  \
# 42                       5.200000e+01                       1.080000e+02
# 43                       2.668532e+13                       5.547740e+12
#
#     ba23b66825fc1c91-Others-permanent  ba23b66825fc1c91-Others-temporary  \
# 42                         407.000000                         202.000000
# 43                        1295.525322                         144.571998
#
#     ba4547c678a9a2e6-Others-permanent  ba4547c678a9a2e6-Others-temporary  \
# 42                       5.150000e+02                       1.500000e+01
# 43                       6.292971e+13                       8.846378e+12
#
#     bce36d2f8aa39d8b-Others-permanent  bce36d2f8aa39d8b-Others-temporary  \
# 42                       4.009000e+03                       3.650000e+02
# 43                       3.003453e+13                       1.126576e+12
#
#     be4424aa54f8d2ae-Others-permanent  be4424aa54f8d2ae-Others-temporary  \
# 42                       8.430000e+02                          15.000000
# 43                       1.473562e+13                          -3.063821
#
#     be8a37473dc63db0-Others-permanent  be8a37473dc63db0-Others-temporary  \
# 42                       1.210000e+03                       1.340000e+02
# 43                       6.108297e+13                       3.852891e+12
#
#     c0019c9a4b4819f2-Others-permanent  c0019c9a4b4819f2-Others-temporary  \
# 42                       5.000000e+01                       0.000000e+00
# 43                       1.217163e+12                       3.215802e+11
#
#     c118b149223ba711-Others-permanent  c118b149223ba711-Others-temporary  \
# 42                       1.500000e+01                          30.000000
# 43                       7.784200e+11                           1.612024
#
#     c129d0cd5f1afd51-Others-permanent  c129d0cd5f1afd51-Others-temporary  \
# 42                       9.400000e+02                           0.000000
# 43                       1.383875e+14                          -1.597043
#
#     c45d8ddba643c0d7-Others-permanent  c45d8ddba643c0d7-Others-temporary  \
# 42                       2.350000e+02                       1.000000e+01
# 43                       5.709177e+12                       6.141581e+11
#
#     cb23149538de1c42-Others-permanent  cb23149538de1c42-Others-temporary  \
# 42                         713.000000                          63.000000
# 43                        1011.705243                          52.164631
#
#     cdc89121a4b9478b-Others-permanent  cdc89121a4b9478b-Others-temporary  \
# 42                       4.500000e+01                       2.400000e+02
# 43                       1.126576e+12                       1.351892e+12
#
#     cead2cbd1f8f0b86-Others-permanent  cead2cbd1f8f0b86-Others-temporary  \
# 42                         634.000000                          48.000000
# 43                         298.381011                          99.643948
#
#     cf96db4cc35ea025-Others-permanent  cf96db4cc35ea025-Others-temporary  \
# 42                       1.000000e+00                       0.000000e+00
# 43                       3.542111e+13                       6.759459e+10
#
#     d0f5f5b9fcecb0d8-Others-permanent  d0f5f5b9fcecb0d8-Others-temporary  \
# 42                          21.000000                          17.000000
# 43                         110.462545                          45.683211
#
#     d42d0e216f57b2ae-Others-permanent  d42d0e216f57b2ae-Others-temporary  \
# 42                       1.400000e+01                       2.000000e+00
# 43                       2.060705e+13                       2.318646e+12
#
#     d6f1f98b1745e004-Others-permanent  d6f1f98b1745e004-Others-temporary  \
# 42                       2.069000e+03                       4.600000e+02
# 43                       1.129073e+14                       5.331720e+12
#
#     d6ffd6d7dfe22d57-Others-permanent  d6ffd6d7dfe22d57-Others-temporary  \
# 42                         672.000000                           0.000000
# 43                         875.605408                         378.327846
#
#     de1994d393ef525a-Others-permanent  de1994d393ef525a-Others-temporary  \
# 42                         545.000000                          30.000000
# 43                           7.416723                          -0.146411
#
#     df19203419d2ea64-Others-permanent  df19203419d2ea64-Others-temporary  \
# 42                       5.500000e+02                       3.600000e+01
# 43                       8.801403e+12                       2.445717e+12
#
#     df2cd1cbe849ebd0-Others-permanent  df2cd1cbe849ebd0-Others-temporary  \
# 42                       1.174000e+03                       0.000000e+00
# 43                       8.528733e+13                       6.603340e+13
#
#     e635f6b0f8a98808-Others-permanent  e635f6b0f8a98808-Others-temporary  \
# 42                         258.000000                           86.00000
# 43                         339.734445                          131.24999
#
#     eac302b92f87d9ca-Others-permanent  eac302b92f87d9ca-Others-temporary  \
# 42                       1.118000e+03                       7.900000e+01
# 43                       4.173742e+13                       3.778446e+13
#
#     ec84c1e86735dc9b-Others-permanent  ec84c1e86735dc9b-Others-temporary  \
# 42                       1.628500e+04                       5.000000e+01
# 43                       1.446334e+14                       2.073783e+14
#
#     f1fd357c5adaa8dc-Others-permanent  f1fd357c5adaa8dc-Others-temporary  \
# 42                       2.260000e+03                           0.000000
# 43                       1.831606e+13                          -0.583602
#
#     f39d21744916469c-Others-permanent  f39d21744916469c-Others-temporary  \
# 42                       2.600000e+02                       0.000000e+00
# 43                       4.799216e+12                       2.253153e+11
#
#     f3c2cc112eb0e6fe-Others-permanent  f3c2cc112eb0e6fe-Others-temporary  \
# 42                       9.500000e+01                       0.000000e+00
# 43                       1.044953e+13                       9.407551e+12
#
#     f4612b8b5a8223b5-Others-permanent  f4612b8b5a8223b5-Others-temporary  \
# 42                          300.00000                            0.00000
# 43                          325.55375                            1.17657
#
#     f67358b81451a8d1-Others-permanent  f67358b81451a8d1-Others-temporary  \
# 42                       6.000000e+00                           4.000000
# 43                       2.966814e+12                           7.104315
#
#     f8e70145d73bd728-Others-permanent  f8e70145d73bd728-Others-temporary  \
# 42                       3.730000e+02                       5.000000e+00
# 43                       1.424761e+13                       7.491790e+11
#
#     fa005e1ffef6032a-Others-permanent  fa005e1ffef6032a-Others-temporary  \
# 42                       3.940000e+02                          10.000000
# 43                       2.573281e+12                          21.974919
#
#     fae378a53734da72-Others-permanent  fae378a53734da72-Others-temporary  \
# 42                       5.950000e+02                       2.900000e+01
# 43                       1.590415e+13                       1.878901e+12
#
#     fda49275fbf5caf6-Others-permanent  fda49275fbf5caf6-Others-temporary
# 42                         350.000000                           5.000000
# 43                         449.058626                          -1.094428

# %% [markdown]
# ## VARMA example

# %%
from statsmodels.tsa.statespace.varmax import VARMAX
from random import random
# fit model
model = VARMAX(X_train.iloc[:, :10], order=(1, 1))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.forecast(steps=2)

# %%
yhat.values.reshape(-1)
# Out:
# array([ 5.85707462e+01,  1.97347327e+00,  5.38858798e+02,  6.51003347e+01,
#         2.15553878e+01,  2.85122270e+01,  2.35913040e+01, -1.19782394e+00,
#         4.54901441e+03,  1.70309062e+02,  5.17438664e+01, -1.45884636e+00,
#         5.09996943e+02,  3.30828368e+01,  1.93070534e+01,  2.72169015e+01,
#         6.88496406e+00, -2.01708291e+00,  4.82217469e+03,  1.77698661e+02])

# %%
score_predictions(x_test[:20], yhat.values.reshape(-1))
# Out:
# [364.8152602399824,
#  1178920.5267740374,
#  7181137038150194.0,
#  1.3092239735868738,
#  -0.8964016682752449]

# %% [markdown]
# ## VARMAX example

# %%
from statsmodels.tsa.statespace.varmax import VARMAX
from random import random
# contrived dataset with dependency
data = list()
for i in range(100):
    v1 = random()
    v2 = v1 + random()
    row = [v1, v2]
    data.append(row)
data_exog = [x + random() for x in range(100)]

# %%
# fit model
model = VARMAX(X_train.iloc[:, 1:5], exog=X_train.iloc[:, 5:7], order=(1, 1))
model_fit = model.fit(disp=False)
# Out:
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "

# %%
# make prediction
yhat = model_fit.forecast(exog=X_test.iloc[:, 11])
print(yhat)
# Out:
#             0307883b5d063703-Others-temporary  \
# 2016-01-01                          -0.283763
#
#             03e477d4ede00e89-Others-permanent  \
# 2016-01-01                         675.128926
#
#             03e477d4ede00e89-Others-temporary  \
# 2016-01-01                         -159.11296
#
#             051e9cc7d7636816-Others-permanent
# 2016-01-01                           9.638296
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'

# %%
from statsmodels.tsa.statespace.varmax import VARMAX
from random import random
# contrived dataset with dependency
data = list()
for i in range(100):
    v1 = random()
    v2 = v1 + random()
    row = [v1, v2]
    data.append(row)
data_exog = [x + random() for x in range(100)]
# fit model
model = VARMAX(data, exog=data_exog, order=(1, 1))
model_fit = model.fit(disp=False)
# make prediction
data_exog2 = [[100]]
yhat = model_fit.forecast(exog=data_exog2)
print(yhat)
# Out:
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# [[0.61147055 1.07143922]]
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# C:\Users\luisr\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
