# %%
print('Rank completo: Diferença percentual da média - grupo de renovação'); print()
for i in range(1, 7):
    a = prct_dif[col_rank==i].to_frame(f'Rank {i} - Diferença percentual da média (%)') * 100
    display(a.round(1))
# Out:
# Rank completo: Diferença percentual da média - grupo de renovação
#                                 Rank 1 - Diferença percentual da média (%)
# total_ARTIGOS_ESPORTIVOS_F2_m4                                       153.0
# NV_D2_OBJETIVIDADE_3m                                                133.2
# total_ARTIGOS_ESPORTIVOS_F3_m4                                       115.9
# FL_VAREJO_F4                                                         107.2
#                                 Rank 2 - Diferença percentual da média (%)
# FL_PET_SHOP_F4                                                        93.0
# FL_ARTIGOS_ELETRONICOS_F3                                             84.1
# total_ARTIGOS_ESPORTIVOS_F1_m4                                        80.6
#                                  Rank 3 - Diferença percentual da média (%)
# FL_BEM_ESTAR_F3                                                        72.7
# CD_Cartao_6m                                                           71.8
# FL_KIDS_F1                                                             67.5
# FL_MATERIAL_DE_CONSTRUCAO_F1                                           67.0
# FL_ENTRETENIMENTO_F1                                                   65.8
# FL_ARTIGOS_ELETRONICOS_F4                                              65.0
# total_ARTIGOS_ELETRONICOS_F4_m4                                        61.1
# FL_VIAGEM_E_TURISMO_F4                                                 56.3
# FL_ELETRODOMESTICO_F2                                                  54.5
# total_PET_SHOP_F4_m4                                                   54.1
#                                                 Rank 4 - Diferença percentual da média (%)
# NV_FC_CPC___Responsavel_6m                                                           -48.5
# FL_POSTO_DE_GASOLINA_F3                                                               46.9
# NV_FC_Promessa_de_pagamento_3m                                                       -46.3
# FL_ENTRETENIMENTO_F3                                                                  45.9
# FL_EDUCACAO_F2                                                                        45.0
# NV_P3_Quitacao_6m                                                                     44.3
# total_PET_SHOP_F3_m4                                                                  44.1
# total_MATERIAL_DE_CONSTRUCAO_F4_m4                                                    42.7
# FL_RESTAURANTE_F4                                                                     42.1
# total_MOVEIS_E_DECORACOES_F1_m4                                                      -41.1
# NV_FC_CONTATO_UTIL_3m                                                                 40.7
# total_VIAGEM_E_TURISMO_F3_m4                                                         -40.1
# FL_VIAGEM_E_TURISMO_F3                                                               -39.7
# total_BEM_ESTAR_F4_m4                                                                -39.2
# total_ARTIGOS_ELETRONICOS_F1_m4                                                      -37.9
# FL_PET_SHOP_F3                                                                        37.8
# FL_AUTOMOVEL_F2                                                                       37.4
# total_LOJAS_DE_COSMETICOS_F4_m4                                                      -37.3
# FL_LOJAS_DE_COSMETICOS_F2                                                             36.6
# NV_BP4_Informa_o_desconto_6m                                                          36.5
# total_ELETRODOMESTICO_F4_m4                                                          -36.3
# total_VIAGEM_E_TURISMO_F2_m4                                                          35.2
# FL_VAREJO_F2                                                                         -34.6
# FL_AUTOMOVEL_F3                                                                      -34.5
# total_MOVEIS_E_DECORACOES_F2_m4                                                      -34.1
# total_PET_SHOP_F2_m4                                                                  33.8
# FL_FARMACIAS_F3                                                                       33.4
# GC_AusenciaRenda_6m                                                                  -32.3
# total_BEM_ESTAR_F2_m4                                                                -32.2
# NV_CX_Rechamadas_6m                                                                  -32.2
# total_VAREJO_F4_m4                                                                    32.1
# total_BEM_ESTAR_F3_m4                                                                -32.1
# FL_ELETRODOMESTICO_F1                                                                -32.0
# FL_ENTRETENIMENTO_F4                                                                  31.9
# NV_CX_PID_6m                                                                          31.9
# NV_P1_Pagamento_parcela_6m                                                           -31.9
# total_FARMACIAS_F4_m4                                                                 30.8
# FL_VESTUARIO_F4                                                                       30.6
# total_LOJAS_DE_DEPARTAMENTO_F1_m4                                                    -30.6
# FL_LOJAS_DE_COSMETICOS_F4                                                             29.3
# NV_DC3_Nao_e_o_responsavel_do_financiamento_3m                                       -28.1
# total_KIDS_F3_m4                                                                      27.8
# NV_C2_GRAVACAO_DA_LIGACAO_6m                                                         -27.4
# FL_LOJAS_DE_COSMETICOS_F3                                                            -26.8
# FL_VESTUARIO_F2                                                                       26.5
# total_EDUCACAO_F1_m4                                                                 -26.0
# NV_BP6_Gera_urgencia_3m                                                              -25.9
#                                     Rank 5 - Diferença percentual da média (%)
# FL_POSTO_DE_GASOLINA_F2                                                  -24.6
# FL_ELETRODOMESTICO_F3                                                     24.4
# total_EDUCACAO_F3_m4                                                      24.2
# QTD_OUTROS                                                               -23.8
# PL_Sem_Condicoes_6m                                                       23.3
# total_VESTUARIO_F2_m4                                                     23.1
# total_FARMACIAS_F1_m4                                                    -22.8
# total_LOJAS_DE_COSMETICOS_F1_m4                                          -22.5
# total_LOJAS_DE_COSMETICOS_F2_m4                                          -22.3
# GC_IsencaoMoraMulta_3m                                                    22.2
# FL_VAREJO_F1                                                              22.1
# CX_Cancelamento_6m                                                        22.0
# FL_ENTRETENIMENTO_F2                                                     -22.0
# FL_MATERIAL_DE_CONSTRUCAO_F3                                              21.7
# FL_POSTO_DE_GASOLINA_F1                                                  -21.7
# P6_RENEGPEDEC_6m                                                          21.6
# total_AUTOMOVEL_F4_m4                                                     21.1
# FL_RESTAURANTE_F3                                                        -21.1
# FL_PET_SHOP_F2                                                            20.8
# total_VESTUARIO_F3_m4                                                     20.2
# Produto_Veiculo_3m                                                        19.9
# GC_OfertaNegociacao_6m                                                   -19.7
# CD_Cartao_3m                                                             -19.5
# MOT_Informacao_6m                                                        -18.9
# FL_BEM_ESTAR_F1                                                           18.8
# MOT_Servicos_6m                                                          -18.6
# NV_C2_GRAVACAO_DA_LIGACAO_3m                                              18.6
# total_ELETRODOMESTICO_F3_m4                                               18.5
# flmat90conta                                                             -18.4
# GC_IsencaoMoraMulta_6m                                                    18.0
# FL_AUTOMOVEL_F1                                                          -17.8
# FL_AUTOMOVEL_F4                                                           17.6
# FL_FARMACIAS_F2                                                          -17.5
# FL_LOJAS_DE_DEPARTAMENTO_F3                                               17.4
# CD_Seguro_6m                                                             -17.4
# Capacidade_de_Pagamento_1                                                -17.3
# QTD_CARTAO                                                                17.0
# FL_VESTUARIO_F3                                                           16.8
# FL_BEM_ESTAR_F2                                                           16.7
# FL_POSTO_DE_GASOLINA_F4                                                   16.7
# FL_RESTAURANTE_F1                                                        -16.6
# FL_MATERIAL_DE_CONSTRUCAO_F4                                             -16.5
# total_MATERIAL_DE_CONSTRUCAO_F2_m4                                        16.4
# Produto_Veiculo_6m                                                        16.2
# FL_ARTIGOS_ELETRONICOS_F2                                                 15.6
# total_FARMACIAS_F2_m4                                                    -15.4
# total_MOVEIS_E_DECORACOES_F3_m4                                          -15.2
# QTD_CP_CONSIGNADO                                                         15.2
# FL_VIAGEM_E_TURISMO_F2                                                   -15.2
# total_POSTO_DE_GASOLINA_F4_m4                                             15.0
#                                    Rank 6 - Diferença percentual da média (%)
# total_ENTRETENIMENTO_F3_m4                                              -14.9
# total_AUTOMOVEL_F3_m4                                                    14.7
# total_LOJAS_DE_DEPARTAMENTO_F4_m4                                        14.6
# total_VAREJO_F3_m4                                                       14.5
# flmat60conta                                                            -14.4
# ...                                                                       ...
# FL_FARMACIAS_F4                                                          -0.4
# flmau60conta                                                              0.4
# total_LOJAS_DE_COSMETICOS_F3_m4                                          -0.3
# GC_AusenciaRenda_3m                                                      -0.3
# FL_LOJAS_DE_DEPARTAMENTO_F2                                               0.2
#
# [113 rows x 1 columns]
