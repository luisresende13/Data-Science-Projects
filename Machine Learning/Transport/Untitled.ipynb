# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# pd.read_excel?

# %%
df = pd.read_excel('1268.xls')

# %%
df
# Out:
#                                              Data.Rio  \
# 0                                                 NaN
# 1   Tabela 1268 - Fluxo médio de passageiros por d...
# 2                                                 NaN
# 3                                   Linha/Estações
# 4                                                 NaN
# 5                                                 NaN
# 6                                               Total
# 7                                            Linha  1
# 8                                             Linha 2
# 9                                             Linha 4
# 10                                                NaN
# 11                                                NaN
# 12  Fonte: Companhia do Metropolitano do Rio de Ja...
# 13                                             Notas:
# 14  1 - Os dados de fluxo médio diário foram revis...
# 15  2- Estações inauguradas em 1998:  Cardeal Arco...
# ...
