# %%
from sklearn.utils import all_estimators
import numpy as np
import pandas as pd
import os
import itertools
from IPython.display import clear_output
import matplotlib.pyplot as plt

import time

from sklearn.preprocessing import MinMaxScaler as mms

# %%
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-6a00893fb3e1> in <module>
# ----> 1 import pandas_profiling
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
conda install -c conda-forge pandas-profiling
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\luisr\anaconda3
#
#   added / updated specs:
#     - pandas-profiling
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.0               |   py38haa244fe_1         3.1 MB  conda-forge
#     pandas-profiling-1.4.1     |                0          40 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas-profiling   conda-forge/win-64::pandas-profiling-1.4.1-0
#
# The following packages will be UPDATED:
#
#   conda                                4.9.2-py38haa244fe_0 --> 4.10.0-py38haa244fe_1
#
#
#
# Downloading and Extracting Packages
#
# pandas-profiling-1.4 | 40 KB     |            |   0%
# pandas-profiling-1.4 | 40 KB     | ####       |  40%
# pandas-profiling-1.4 | 40 KB     | ########## | 100%
# pandas-profiling-1.4 | 40 KB     | ########## | 100%
#
# conda-4.10.0         | 3.1 MB    |            |   0%
# conda-4.10.0         | 3.1 MB    | 7          |   7%
# conda-4.10.0         | 3.1 MB    | ##2        |  23%
# conda-4.10.0         | 3.1 MB    | ###2       |  32%
# conda-4.10.0         | 3.1 MB    | #####6     |  56%
# conda-4.10.0         | 3.1 MB    | #######5   |  75%
# conda-4.10.0         | 3.1 MB    | ########9  |  89%
# conda-4.10.0         | 3.1 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-2.11.0-py2.py3-none-any.whl (243 kB)
# Requirement already satisfied, skipping upgrade: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\luisr\anaconda3\lib\site-packages (from pandas-profiling) (1.0.5)
# Requirement already satisfied, skipping upgrade: jinja2>=2.11.1 in c:\users\luisr\anaconda3\lib\site-packages (from pandas-profiling) (2.11.2)
# Requirement already satisfied, skipping upgrade: attrs>=19.3.0 in c:\users\luisr\anaconda3\lib\site-packages (from pandas-profiling) (19.3.0)
# Collecting tqdm>=4.48.2
#   Downloading tqdm-4.60.0-py2.py3-none-any.whl (75 kB)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.0 in c:\users\luisr\anaconda3\lib\site-packages (from pandas-profiling) (1.19.5)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Requirement already satisfied, skipping upgrade: requests>=2.24.0 in c:\users\luisr\anaconda3\lib\site-packages (from pandas-profiling) (2.24.0)
# Collecting tangled-up-in-unicode>=0.0.6
#   Downloading tangled_up_in_unicode-0.0.7-py3-none-any.whl (3.1 MB)
# Requirement already satisfied, skipping upgrade: scipy>=1.4.1 in c:\users\luisr\anaconda3\lib\site-packages (from pandas-profiling) (1.5.0)
# Collecting visions[type_image_path]==0.6.0
#   Downloading visions-0.6.0-py3-none-any.whl (75 kB)
# Requirement already satisfied, skipping upgrade: seaborn>=0.10.1 in c:\users\luisr\anaconda3\lib\site-packages (from pandas-profiling) (0.10.1)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Requirement already satisfied, skipping upgrade: joblib in c:\users\luisr\anaconda3\lib\site-packages (from pandas-profiling) (0.16.0)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.2.0 in c:\users\luisr\anaconda3\lib\site-packages (from pandas-profiling) (3.2.2)
# Requirement already satisfied, skipping upgrade: ipywidgets>=7.5.1 in c:\users\luisr\anaconda3\lib\site-packages (from pandas-profiling) (7.5.1)
# Collecting confuse>=1.0.0
#   Downloading confuse-1.4.0-py2.py3-none-any.whl (21 kB)
# Collecting phik>=0.10.0
#   Downloading phik-0.11.2.tar.gz (1.1 MB)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\luisr\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\luisr\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2.8.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\luisr\anaconda3\lib\site-packages (from jinja2>=2.11.1->pandas-profiling) (1.1.1)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\luisr\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.25.9)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\luisr\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\luisr\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\luisr\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.0.4)
# Requirement already satisfied, skipping upgrade: networkx>=2.4 in c:\users\luisr\anaconda3\lib\site-packages (from visions[type_image_path]==0.6.0->pandas-profiling) (2.4)
# Requirement already satisfied, skipping upgrade: Pillow; extra == "type_image_path" in c:\users\luisr\anaconda3\lib\site-packages (from visions[type_image_path]==0.6.0->pandas-profiling) (7.2.0)
# ERROR: phik 0.11.2 has requirement scipy>=1.5.2, but you'll have scipy 1.5.0 which is incompatible.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Acesso negado: 'C:\\Users\\Public\\Documents\\Wondershare\\CreatorTemp\\pip-uninstall-ux4macbz\\tqdm.exe'
# Consider using the `--user` option or check the permissions.
# Collecting imagehash; extra == "type_image_path"
#   Downloading ImageHash-4.2.0-py2.py3-none-any.whl (295 kB)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\luisr\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\luisr\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\luisr\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.4.7)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in c:\users\luisr\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (4.3.3)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in c:\users\luisr\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (5.0.7)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in c:\users\luisr\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (3.5.1)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in c:\users\luisr\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (5.3.2)
# Requirement already satisfied, skipping upgrade: ipython>=4.0.0; python_version >= "3.3" in c:\users\luisr\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (7.16.1)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\luisr\anaconda3\lib\site-packages (from confuse>=1.0.0->pandas-profiling) (5.3.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\luisr\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (1.15.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in c:\users\luisr\anaconda3\lib\site-packages (from networkx>=2.4->visions[type_image_path]==0.6.0->pandas-profiling) (4.4.2)
# Requirement already satisfied, skipping upgrade: PyWavelets in c:\users\luisr\anaconda3\lib\site-packages (from imagehash; extra == "type_image_path"->visions[type_image_path]==0.6.0->pandas-profiling) (1.1.1)
# Requirement already satisfied, skipping upgrade: ipython-genutils in c:\users\luisr\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1->pandas-profiling) (0.2.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in c:\users\luisr\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (4.6.3)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\luisr\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (3.2.0)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in c:\users\luisr\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (6.0.3)
# Requirement already satisfied, skipping upgrade: jupyter-client in c:\users\luisr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (6.1.6)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in c:\users\luisr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (6.0.4)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in c:\users\luisr\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (49.2.0.post20200714)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\luisr\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (3.0.5)
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\luisr\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.7.5)
# Requirement already satisfied, skipping upgrade: pygments in c:\users\luisr\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (2.6.1)
# Requirement already satisfied, skipping upgrade: backcall in c:\users\luisr\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.2.0)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\luisr\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.4.3)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\luisr\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.17.1)
# Requirement already satisfied, skipping upgrade: pywin32>=1.0; sys_platform == "win32" in c:\users\luisr\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (227)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in c:\users\luisr\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (0.16.0)
# Requirement already satisfied, skipping upgrade: prometheus-client in c:\users\luisr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.0)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in c:\users\luisr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.3)
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in c:\users\luisr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (19.0.1)
# Requirement already satisfied, skipping upgrade: nbconvert in c:\users\luisr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (5.6.1)
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\luisr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.5.0)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\luisr\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.2.5)
# Requirement already satisfied, skipping upgrade: parso<0.8.0,>=0.7.0 in c:\users\luisr\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.7.0)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in c:\users\luisr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.4)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\luisr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.3)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\luisr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.4.2)
# Requirement already satisfied, skipping upgrade: bleach in c:\users\luisr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (3.1.5)
# Requirement already satisfied, skipping upgrade: testpath in c:\users\luisr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.4.4)
# Requirement already satisfied, skipping upgrade: defusedxml in c:\users\luisr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.6.0)
# Requirement already satisfied, skipping upgrade: packaging in c:\users\luisr\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (20.4)
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\luisr\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.5.1)
# Building wheels for collected packages: htmlmin, phik
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27085 sha256=f3ed34aa31588d75e3aaddbca299d216d0a7e41cf334ab2b4fa18c8745bfc857
#   Stored in directory: c:\users\luisr\appdata\local\pip\cache\wheels\23\14\6e\4be5bfeeb027f4939a01764b48edd5996acf574b0913fe5243
#   Building wheel for phik (setup.py): started
#   Building wheel for phik (setup.py): finished with status 'done'
#   Created wheel for phik: filename=phik-0.11.2-py3-none-any.whl size=1107415 sha256=bc079014120e05639b455251bfa8358956b5e56b18304149d283f39588ca2e0d
#   Stored in directory: c:\users\luisr\appdata\local\pip\cache\wheels\72\9a\23\097c93fd8341220d92674891b6a9a30f0e389719d9b7291bd2
# Successfully built htmlmin phik
# Installing collected packages: tqdm, missingno, tangled-up-in-unicode, imagehash, visions, htmlmin, confuse, phik, pandas-profiling
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.47.0
#     Uninstalling tqdm-4.47.0:
#       Successfully uninstalled tqdm-4.47.0

# %%
from pandas_profiling import ProfileReport

# %%
import re

# %%
def intersection(lists):
    a=set(lists[0])
    for i in range(1,len(lists)):
        a = a.intersection(lists[i])
    return a

def n_top_intersection_analysis(top_lists):
    
    n_lists = len(top_lists)
    n_top_max = len(top_lists[0])    
    len_inter = []
    for i in range(1, n_top_max+1):
        
        top_lists_n = [top_lists[j][:i] for j in range(n_lists)]
        
        inter = len(intersection(top_lists_n))
        ttl=len(np.unique(np.array(top_lists_n)))
        len_inter.append([i, inter, inter/i, ttl, inter/ttl, ttl/i])

    len_inter_df = pd.DataFrame(len_inter, columns=['n top colunas mais importantes', 'interseção', 'interseção por n top',
                                                    'colunas unicas', 'interseção por colunas unicas', 'colunas unicas por n top'])
    return len_inter_df

def n_members_intersection_analysis(top_lists_org, n_members=2, rank_degree=2, rank_step=1):
       
    n_lists_org = len(top_lists_org)
    n_top_max = len(top_lists_org[0])    
    
    groups = list(itertools.combinations(range(n_lists_org), n_members))
    n_groups = len(groups)
    groups_stats = []
    cnt_grp = 0
    
    for group in groups:
              
        
        top_lists = [top_lists_org[member] for member in group]
        n_lists = len(top_lists)

        
        loop = np.array(range(rank_step, n_top_max+1, rank_step))**rank_degree
        stop=0
        for i in loop:
    
            if i>=n_top_max+1:
                stop+=1
                i = n_top_max+1
                if stop==2: break

            clear_output(wait=True)
            print('Grupo {}/{} - {}/{}'.format(cnt_grp, n_groups, i, n_top_max))
                 
            top_lists_n = [top_lists[j][:i] for j in range(n_lists)]

            inter = len(intersection(top_lists_n))
            unique = len(np.unique(np.array(top_lists_n)))

            groups_stats.append([group, n_members, i, inter, inter/i, unique, inter/unique, unique/i])
        
        cnt_grp+=1

    groups_df = pd.DataFrame(groups_stats, columns=['group', 'n_members', 'n top colunas mais importantes', 'interseção', 'interseção por n top',
                                                        'colunas unicas', 'interseção por colunas unicas', 'colunas unicas por n top'])
    
    return groups_df

def n_top_combinations_intersection_analyses(top_lists_org, max_members, member_step, rank_degree=2, rank_step=1):
    
    n_members_lst = []
    for n_members in range(2, max_members+1, member_step):
        
        n_stats = n_members_intersection_analysis(top_lists_org, n_members=n_members, rank_degree=rank_degree, rank_step=rank_step)
        n_members_lst.append(n_stats)
    
    n_members_df = pd.concat(n_members_lst, axis=0)
    
    return n_members_df

# %%
def groups_inter(n_members_df0, n_members=2, x_col='n top colunas mais importantes', xlim=None, ylim=None, figsize=(14,12)):
    
    n_members_df = n_members_df0[n_members_df0['n_members']==n_members]
    groups = n_members_df['group'].unique()
    n_grps=len(groups)
    
    fig = plt.figure(figsize=figsize)
    axs = [fig.add_subplot(3,2,i) for i in range(1,6)]
    for i, col in enumerate(n_members_df.columns[3:]):

        
        cnt_grp=1
        
        for group in groups:
            
            clear_output(wait=True)
            print('Desenhando Variável {}/{} - Grupo {}/{}'.format(i+1, 5, cnt_grp, n_grps))
            n_members_df[n_members_df['group']==group].plot(x_col, col, ax=axs[i])
            cnt_grp+=1
            
        
        axs[i].legend([])
        axs[i].set(xlim=xlim, ylim=ylim, title=col)
        axs[i].grid()
        
    plt.show()
    plt.pause(0.1)

def members_inter(n_members_df, x_col='n top colunas mais importantes', xlim=None, ylim=None, marker=None):
    
    fig = plt.figure(figsize=(14,9))

    axs = [fig.add_subplot(3,2,i) for i in range(1,6)]

    for i, col in enumerate(n_members_df.columns[3:]):

        clear_output(wait=True)
        
        for member in range(2, n_members_df['n_members'].max()+1):
            
            #n_members_df.groupby(['n_members', x_col]).mean().reset_index()
            n_members_df[n_members_df['n_members']==member].groupby([x_col]).mean().reset_index().plot(x_col, col, ax=axs[i], marker=marker)
        
        axs[i].legend([])
        axs[i].set(xlim=xlim, ylim=ylim, title=col)
        axs[i].grid()
        
    plt.show()
    plt.pause(0.1)

# %%
def scatter_3d(data, xyz, how='scatter', figsize=(8,5), c=None, cmap=plt.get_cmap('Spectral')):
    
    x, y, z = [data[X] for X in xyz]
    xlabel, ylabel, zlabel = [X for X in xyz]
    if type(c)!=type(None):
        print('Alterando escala para esquema de cores...')
        
        labels_trans = mms().fit_transform(data[[c]].values).ravel()
        c = cmap(labels_trans)
    
    if how=='rotate':
        for angle in range(0, 360, 10):

            fig = plt.figure(figsize=figsize)
            axs = fig.add_subplot(projection='3d')
            axs.scatter(x, y, z, c=c)
            axs.set(xlabel=xlabel, ylabel=ylabel, zlabel=zlabel)
            
            axs.view_init(8, angle)
            clear_output(wait=True)
            plt.show()
            plt.pause(0.01)

    else:
        print('Configurando figura...')
        clear_output(wait=True)
        fig = plt.figure(figsize=figsize)
        axs = fig.add_subplot(projection='3d')
        axs.set(xlabel=xlabel, ylabel=ylabel, zlabel=zlabel)

        if how=='scatter':
            print('Desenhando pontos...')
            axs.scatter(x, y, z, c=c)
            print('Imprimindo pontos...')
            time.sleep(0.6)
            plt.show()
            plt.pause(0.1)
            print('Pontos desenhandos!')
        elif how=='trisurf':
            axs.plot_trisurf(x, y, z)   


def lines_3d(data, xyz, how='scatter', figsize=(8,5), c='label', cmap=plt.get_cmap('Spectral')):
    
    xlabel, ylabel, zlabel = [X for X in xyz]
    fitted_mms = mms().fit(data[[c]].values)
    
    if how=='rotate':
        for angle in range(0, 360, 10):

            fig = plt.figure(figsize=figsize)
            axs = fig.add_subplot(projection='3d')
            axs.scatter(x, y, z, c=c)
            axs.set(xlabel=xlabel, ylabel=ylabel, zlabel=zlabel)
            
            axs.view_init(8, angle)
            clear_output(wait=True)
            plt.show()
            plt.pause(0.01)

    else:
        print('Configurando figura...')
        clear_output(wait=True)
        fig = plt.figure(figsize=figsize)
        axs = fig.add_subplot(projection='3d')
        axs.set(xlabel=xlabel, ylabel=ylabel, zlabel=zlabel)
    
        groups = data['group'].unique()
        n_grps = len(groups)
        for grp, group in enumerate(groups):
                
            grp_data = data[data['group']==group]
            grp_c = grp_data[c]
            x, y, z = [grp_data[X] for X in xyz]

            if type(c)!=type(None):
                
                labels_trans = fitted_mms.transform(grp_data[[c]].values).ravel()
                c_plot = cmap(labels_trans)[0]
            
            clear_output(wait=True)
            print('Desenhando linhas... {}/{}'.format(grp, n_grps))
            axs.plot(x, y, z, color=c_plot)

            
        print('Imprimindo pontos...')
        time.sleep(0.6)
        plt.show()
        plt.pause(0.1)
        print('Pontos Impressos!')

# %%
def simple_groups_inter(n_members_df, cols=['interseção por n top'], n_members=2, x_col='n top colunas mais importantes', figsize=(20,12), xlim=None, ylim=None, colors=None, legend=[]):
    
    if cols==None: cols = n_members_df.columns[3:-1].tolist()

    groups = n_members_df['group'].unique()
    labels = n_members_df.groupby('group').mean()['label'].loc[groups].values
    
    n_grps=len(groups)
    if type(colors)==type(None): 
        colors=[None]*n_grps
    elif colors=='auto':
        colors_float = n_members_df.groupby('group').mean()[['label']].loc[groups]
        colors=cmap(mms().fit_transform(colors_float).ravel())
    elif type(colors)==type(dict()):
        colors = [colors[name] for name in groups]

   
    fig = plt.figure(figsize=figsize)
    axs = [fig.add_subplot(3,2,i) for i in range(1, len(cols)+1)]
    for i, col in enumerate(cols):
        
        cnt_grp=1
        for group, color, label in zip(groups, colors, labels):
            
            group_df = n_members_df[n_members_df['group']==group]
            
            clear_output(wait=True)
            print('Desenhando Variável {}/{} - Grupo {}/{}'.format(i+1, len(cols), cnt_grp, n_grps))
            axs[i].plot(group_df[x_col], group_df[col], c=color)
            cnt_grp+=1
            
        
        axs[i].legend([])
        axs[i].set(xlim=xlim, ylim=ylim, title=col)
        axs[i].grid()
        
    plt.show()
    plt.pause(0.1)

# %%
def as_tuple(str_tuple_lst):
    new_lst = []
    for str_tuple in str_tuple_lst:
        
        new_lst+=[int(re.findall('[0-9]*,', str_tuple)[0][:-1]), int(re.findall(' [0-9]*', str_tuple)[0][1:])]

    return np.unique(new_lst)

# %%
def extract_ranks(X, names):
    
    tops = []
    labels = X['label'].unique()
    for i in labels:

        top_names = as_tuple(X[X['label']==i].index.tolist())
        top_names = [names[name] for name in top_names]
        tops.append(top_names)

    tops_df = pd.DataFrame(tops, index=labels).T
    
    return tops_df

# %%
colors_dict = {label:c[label] for label in (X['label'].unique())}

# %%
data = members_2_c
c='label'
labels_trans = mms().fit_transform(data[[c]].values).ravel()

# %%
labels_map = cmap(labels_trans)

# %% [markdown]
# ### Recarregando Ranks

# %%
ranks_path = 'Feature Selection/Ranks/'

ranks_files = os.listdir(ranks_path)

ranks_lst = [pd.read_csv(ranks_path+rank_file, index_col=0) for rank_file in ranks_files]

# %%
coef_names = [col[:-4] for col in ranks_files]

# %%
ranks_df = pd.concat(ranks_lst, axis=1)
ranks_df.columns = coef_names[:]

# %% [markdown]
# # Ranks Analysis

# %% [markdown]
# ### Ordenando Ranks Carregados

# %%
sorted_ranks_lst = [rank.reset_index().sort_values(['0', 'index'])['index'].tolist() for rank in ranks_lst]

# %% [markdown]
# ### Contagem do N° de Combinações de 18 para grupos de tamanho n

# %%
n_items = list(range(1, len(coef_names)+1))

n_combs = [len(list(itertools.combinations(n_items, i))) for i in n_items[1:]]

plt.bar(n_items[1:], n_combs)
plt.xticks(n_items[1:])
plt.grid()
plt.show()

# %% [markdown]
# ### Análise da interseção para combinações de 2 (grau 2)

# %%
members_2 = n_members_intersection_analysis(sorted_ranks_lst, n_members=2, rank_step=1, rank_degree=2)
# Out:
# Grupo 152/153 - 8820/8819

# %% [markdown]
# ### Análise da interseção para combinações de 2 a 5

# %%
members_to_5 = n_top_combinations_intersection_analyses(sorted_ranks_lst, max_members=5, member_step=1, rank_degree=5, rank_step=1)
# Out:
# Grupo 8567/8568 - 8820/8819

# %% [markdown]
# ### Análise da interseção para combinações de 2 (COMPLETA)

# %%
members_2_full = n_members_intersection_analysis(top_lists_org = sorted_ranks_lst, n_members=2, rank_step=1, rank_degree=1)
# Out:
# Grupo 152/153 - 8819/8819

# %% [markdown]
# ### Salvando Análises

# %%
#members_to_5.to_csv('Feature Selection/análise_interseção_ranks_até_5_membros.csv')
print(datetime.now())
# Out:
# 2021-03-31 22:45:16.991634

# %%
#members_2_full.to_csv('Feature Selection/análise_interseção_combinações_de2_ranks_completa.csv')
print(datetime.now())
# Out:
# 2021-04-01 15:24:58.109669

# %% [markdown]
# ### Recarregando

# %%
members_2 = pd.read_csv('Feature Selection/análise_interseção_combinações_de2_ranks_completa.csv', index_col=0)

# %% [markdown]
# ### Imprimindo Resultado Geral

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.set_style('darkgrid')

# %%
members_inter(members_to_5)

# %%
simple_groups_inter(members_2, cols=['interseção por n top'])
# Out:
# Desenhando Variável 1/1 - Grupo 153/153

# %%
groups_inter(members_2)

# %% [markdown]
# # AGRUPANDO

# %%
from clusteval import clusteval

# %%
def build_X(df, n_top, cols):

    x_col = 'n top colunas mais importantes'
    X = df[df[x_col]==n_top].set_index('group').iloc[:, cols]
    
    return X

# %%
def cluster_X(X, cluster='kmeans', cmap=plt.get_cmap('Spectral')):

    ce = clusteval(cluster=cluster)
    ce_dict = ce.fit(X.values)
    X['label'] = ce_dict['labx']
#    c = [cmap(np.random.random()) for i in range(len(X['label'].unique()))]
    
    n_labels = len(X['label'].unique())
    c = cmap(mms().fit_transform(X['label'].unique().reshape(n_labels,1)).ravel())
    colors_dict = {name:c[label] for name, label in zip(X.index, X['label'])}
    return X, colors_dict, c

# %%
cols_combs = list(itertools.combinations(members_2.columns[-6:], 3))
cmap = plt.get_cmap('Spectral')

# %% [markdown]
# # 1. Usando Média em 4000

# %%
X = build_X(members_2, n_top=4000, cols=[-4])

# %%
X, colors_dict, c = cluster_X(X, cluster='kmeans')
# Out:
#  13%|██████████▊                                                                        | 3/23 [00:00<00:00, 26.86it/s]
# [clusteval] >Fit using kmeans with metric: euclidean, and linkage: ward
# [clusteval] >Evaluate using silhouette.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:01<00:00, 15.24it/s]
# [clusteval] >Optimal number clusters detected: [5].
# [clusteval] >Fin.

# %%
members_2_c = pd.merge(members_2, X.reset_index()[['group', 'label']], on='group')

# %%
simple_groups_inter(members_2_c, cols=['interseção por n top'],
                    n_members=2, x_col='n top colunas mais importantes',
                    figsize=(25,15), xlim=None, ylim=None, colors=colors_dict,
                    legend=[])
# Out:
# Desenhando Variável 1/1 - Grupo 153/153

# %%
for cols in cols_combs:
    lines_3d(members_2_c, cols, how='scatter', c='label')
    print('Desenho Carregado')
    time.sleep(1)
    if input()=='exit': break

# %%
ranks_1800 = extract_ranks(X, ranks_files); ranks_1800
# Out:
#                                  -1                                3  \
# 0            AdaBoostClassifier.csv           AdaBoostClassifier.csv
# 1                   BernoulliNB.csv                 ComplementNB.csv
# 2                  ComplementNB.csv       DecisionTreeClassifier.csv
# 3        DecisionTreeClassifier.csv          ExtraTreeClassifier.csv
# 4           ExtraTreeClassifier.csv   GradientBoostingClassifier.csv
# 5          ExtraTreesClassifier.csv                    LinearSVC.csv
# 6    GradientBoostingClassifier.csv           LogisticRegression.csv
# 7    LinearDiscriminantAnalysis.csv         LogisticRegressionCV.csv
# 8                     LinearSVC.csv                MultinomialNB.csv
# 9            LogisticRegression.csv  PassiveAggressiveClassifier.csv
# 10         LogisticRegressionCV.csv                   Perceptron.csv
# 11                MultinomialNB.csv                SGDClassifier.csv
# 12  PassiveAggressiveClassifier.csv                             None
# 13                   Perceptron.csv                             None
# 14       RandomForestClassifier.csv                             None
# 15              RidgeClassifier.csv                             None
# 16            RidgeClassifierCV.csv                             None
# 17                SGDClassifier.csv                             None
#
#                                   0                                1  \
# 0                   BernoulliNB.csv                  BernoulliNB.csv
# 1                  ComplementNB.csv                 ComplementNB.csv
# 2    LinearDiscriminantAnalysis.csv         ExtraTreesClassifier.csv
# 3                     LinearSVC.csv   LinearDiscriminantAnalysis.csv
# 4            LogisticRegression.csv                    LinearSVC.csv
# 5          LogisticRegressionCV.csv           LogisticRegression.csv
# 6                 MultinomialNB.csv         LogisticRegressionCV.csv
# 7   PassiveAggressiveClassifier.csv                MultinomialNB.csv
# 8                    Perceptron.csv  PassiveAggressiveClassifier.csv
# 9               RidgeClassifier.csv                   Perceptron.csv
# 10            RidgeClassifierCV.csv       RandomForestClassifier.csv
# 11                SGDClassifier.csv              RidgeClassifier.csv
# 12                             None            RidgeClassifierCV.csv
# 13                             None                SGDClassifier.csv
# 14                             None                             None
# 15                             None                             None
# 16                             None                             None
# 17                             None                             None
#
#                                   2
# 0                   BernoulliNB.csv
# 1          ExtraTreesClassifier.csv
# 2    LinearDiscriminantAnalysis.csv
# 3                     LinearSVC.csv
# 4            LogisticRegression.csv
# 5          LogisticRegressionCV.csv
# 6   PassiveAggressiveClassifier.csv
# 7                    Perceptron.csv
# 8        RandomForestClassifier.csv
# 9               RidgeClassifier.csv
# 10            RidgeClassifierCV.csv
# 11                SGDClassifier.csv
# 12                             None
# 13                             None
# 14                             None
# 15                             None
# 16                             None
# 17                             None

# %% [markdown]
# # 2. Usando Média 1800

# %%
X = build_X(members_2, 1800, [-4])

# %%
X, colors_dict, c = cluster_X(X, 'kmeans')
# Out:
#  17%|██████████████▍                                                                    | 4/23 [00:00<00:00, 28.05it/s]
# [clusteval] >Fit using kmeans with metric: euclidean, and linkage: ward
# [clusteval] >Evaluate using silhouette.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:01<00:00, 15.58it/s]
# [clusteval] >Optimal number clusters detected: [8].
# [clusteval] >Fin.

# %%
members_2_c = pd.merge(members_2, X.reset_index()[['group', 'label']], on='group')

# %%
simple_groups_inter(members_2_c, cols=['interseção por n top'],
                    n_members=2, x_col='n top colunas mais importantes',
                    figsize=(25,15), xlim=None, ylim=None, colors=colors_dict) # Feito com Média Geral
# Out:
# Desenhando Variável 1/1 - Grupo 153/153

# %%
legend = {label:c[label] for label in X['label'].unique()}

fig, ax = plt.subplots(figsize=(10,1))
axs = ax.bar(legend.keys(), np.ones(len(legend)))
for child, color in zip(axs.get_children(), legend.values()):
    child.set_color(color)

# %%
ranks_1800 = extract_ranks(X, ranks_files); ranks_1800
# Out:
#                                  -1                           6  \
# 0            AdaBoostClassifier.csv      AdaBoostClassifier.csv
# 1                   BernoulliNB.csv  DecisionTreeClassifier.csv
# 2                  ComplementNB.csv                        None
# 3        DecisionTreeClassifier.csv                        None
# 4           ExtraTreeClassifier.csv                        None
# 5          ExtraTreesClassifier.csv                        None
# 6    GradientBoostingClassifier.csv                        None
# 7    LinearDiscriminantAnalysis.csv                        None
# 8                     LinearSVC.csv                        None
# 9            LogisticRegression.csv                        None
# 10         LogisticRegressionCV.csv                        None
# 11                MultinomialNB.csv                        None
# 12  PassiveAggressiveClassifier.csv                        None
# 13                   Perceptron.csv                        None
# 14       RandomForestClassifier.csv                        None
# 15              RidgeClassifier.csv                        None
# 16            RidgeClassifierCV.csv                        None
# 17                SGDClassifier.csv                        None
#
#                                  1                  4  \
# 0           AdaBoostClassifier.csv    BernoulliNB.csv
# 1       DecisionTreeClassifier.csv   ComplementNB.csv
# 2          ExtraTreeClassifier.csv  MultinomialNB.csv
# 3   GradientBoostingClassifier.csv               None
# 4                             None               None
# 5                             None               None
# 6                             None               None
# 7                             None               None
# 8                             None               None
# 9                             None               None
# 10                            None               None
# 11                            None               None
# 12                            None               None
# 13                            None               None
# 14                            None               None
# 15                            None               None
# 16                            None               None
# 17                            None               None
#
#                                   0                                3  \
# 0                   BernoulliNB.csv                  BernoulliNB.csv
# 1                  ComplementNB.csv         ExtraTreesClassifier.csv
# 2          ExtraTreesClassifier.csv   LinearDiscriminantAnalysis.csv
# 3    LinearDiscriminantAnalysis.csv                    LinearSVC.csv
# 4                     LinearSVC.csv           LogisticRegression.csv
# 5            LogisticRegression.csv         LogisticRegressionCV.csv
# 6          LogisticRegressionCV.csv  PassiveAggressiveClassifier.csv
# 7                 MultinomialNB.csv                   Perceptron.csv
# 8   PassiveAggressiveClassifier.csv       RandomForestClassifier.csv
# 9                    Perceptron.csv              RidgeClassifier.csv
# 10       RandomForestClassifier.csv            RidgeClassifierCV.csv
# 11              RidgeClassifier.csv                SGDClassifier.csv
# 12            RidgeClassifierCV.csv                             None
# 13                SGDClassifier.csv                             None
# 14                             None                             None
# 15                             None                             None
# 16                             None                             None
# 17                             None                             None
#
#                                  5                                2
# 0                 ComplementNB.csv                 ComplementNB.csv
# 1   LinearDiscriminantAnalysis.csv                    LinearSVC.csv
# 2                MultinomialNB.csv           LogisticRegression.csv
# 3                             None         LogisticRegressionCV.csv
# 4                             None                MultinomialNB.csv
# 5                             None  PassiveAggressiveClassifier.csv
# 6                             None                   Perceptron.csv
# 7                             None                SGDClassifier.csv
# 8                             None                             None
# 9                             None                             None
# 10                            None                             None
# 11                            None                             None
# 12                            None                             None
# 13                            None                             None
# 14                            None                             None
# 15                            None                             None
# 16                            None                             None
# 17                            None                             None

# %% [markdown]
# # 2. Usando Média 200

# %%
X = build_X(members_2, 300, [-4])

# %%
X, colors_dict, c = cluster_X(X, 'kmeans')
# Out:
#   4%|███▌                                                                            | 11/245 [00:00<00:02, 104.05it/s]
# [clusteval] >Fit using dbscan with metric: euclidean, and linkage: ward
# [clusteval] >Normalize data (unit variance, zero-mean).
# [clusteval] >Gridsearch across epsilon..
# [clusteval] >Evaluate using silhouette..
# 100%|███████████████████████████████████████████████████████████████████████████████| 245/245 [00:01<00:00, 148.46it/s]
# [clusteval] >Compute dendrogram threshold.
# [clusteval] >Optimal number clusters detected: [3].
# [clusteval] >Fin.

# %%
members_2_c = pd.merge(members_2, X.reset_index()[['group', 'label']], on='group')

# %%
simple_groups_inter(members_2_c, cols=['interseção por n top'],
                    n_members=2, x_col='n top colunas mais importantes',
                    figsize=(25,15), xlim=None, ylim=None, colors=colors_dict) # Feito com Média Geral
# Out:
# Desenhando Variável 1/1 - Grupo 153/153

# %%
legend = {label:c[label] for label in X['label'].unique()}

fig, ax = plt.subplots(figsize=(10,1))
axs = ax.bar(legend.keys(), np.ones(len(legend)))
for child, color in zip(axs.get_children(), legend.values()):
    child.set_color(color)

# %%
ranks_1800 = extract_ranks(X, ranks_files); ranks_1800
# Out:
#                                   0                                1  \
# 0            AdaBoostClassifier.csv           AdaBoostClassifier.csv
# 1                   BernoulliNB.csv                  BernoulliNB.csv
# 2                  ComplementNB.csv                 ComplementNB.csv
# 3        DecisionTreeClassifier.csv       DecisionTreeClassifier.csv
# 4           ExtraTreeClassifier.csv                    LinearSVC.csv
# 5          ExtraTreesClassifier.csv           LogisticRegression.csv
# 6    GradientBoostingClassifier.csv         LogisticRegressionCV.csv
# 7    LinearDiscriminantAnalysis.csv                MultinomialNB.csv
# 8                     LinearSVC.csv  PassiveAggressiveClassifier.csv
# 9            LogisticRegression.csv                   Perceptron.csv
# 10         LogisticRegressionCV.csv                SGDClassifier.csv
# 11                MultinomialNB.csv                             None
# 12  PassiveAggressiveClassifier.csv                             None
# 13                   Perceptron.csv                             None
# 14       RandomForestClassifier.csv                             None
# 15              RidgeClassifier.csv                             None
# 16            RidgeClassifierCV.csv                             None
# 17                SGDClassifier.csv                             None
#
#                                   2
# 0            LogisticRegression.csv
# 1          LogisticRegressionCV.csv
# 2   PassiveAggressiveClassifier.csv
# 3                    Perceptron.csv
# 4                 SGDClassifier.csv
# 5                              None
# 6                              None
# 7                              None
# 8                              None
# 9                              None
# 10                             None
# 11                             None
# 12                             None
# 13                             None
# 14                             None
# 15                             None
# 16                             None
# 17                             None

# %%
import imblearn

# %%
from imblearn import ensemble??
# Out:
# Type:        module
# String form: <module 'imblearn.ensemble' from 'C:\\Users\\luisr\\anaconda3\\lib\\site-packages\\imblearn\\ensemble\\__init__.py'>
# File:        c:\users\luisr\anaconda3\lib\site-packages\imblearn\ensemble\__init__.py
# Source:
# """
# The :mod:`imblearn.ensemble` module include methods generating
# under-sampled subsets combined inside an ensemble.
# """
#
# from ._easy_ensemble import EasyEnsembleClassifier
# from ._bagging import BalancedBaggingClassifier
# from ._forest import BalancedRandomForestClassifier
# from ._weight_boosting import RUSBoostClassifier
#
# __all__ = [
#     "BalancedBaggingClassifier",
#     "BalancedRandomForestClassifier",
#     "EasyEnsembleClassifier",
#     "RUSBoostClassifier",
# ]

# %%
from imblearn import ensemble

# %%
# ?from imblearn import ensemble
# Out:
# Object `from imblearn import ensemble` not found.

# %%
from imblearn.ensemble import EasyEnsembleClassifier
from imblearn.ensemble import BalancedBaggingClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.ensemble import RUSBoostClassifier

imb_ensemble = [
    BalancedBaggingClassifier,
    BalancedRandomForestClassifier,
    EasyEnsembleClassifier,
    RUSBoostClassifier]
imb_names = [
    "BalancedBaggingClassifier",
    "BalancedRandomForestClassifier",
    "EasyEnsembleClassifier",
    "RUSBoostClassifier"]
imb_params = [imb().get_params() for imb in imb_ensemble]
